# %%
from pymongo import Connection
import sklearn
from pymongo import MongoClient
import sys
sys.path.insert(0, '/home/thomas/Projects/Watchlist/pythonApp/vendor/mongoqueue/mongoqueue')
from mongoqueue import MongoQueue
import time
import string
from random import randint
from __future__ import division

# %%
uri = 'mongodb://localhost/appdb'
client = MongoClient(uri)

# %%
queue = MongoQueue(
client.appdb.jobqueue,
consumer_id="consumer-1",
timeout=300,
max_attempts=3)

# %%
movieCache = dict();
allMovies = 0;

# %%
def getMovie(movieId):
    if movieId in movieCache:
        return movieCache[movieId]
    else:
        m = client.appdb.movies.find_one({"_id":movieId})
        if (m) :
            movieCache[movieId] = m
        else :
            raise Exception("You are a terrible coder")
        return m

# %%
def updateMovies(userId, newMovies, myMovies):
    newSet = dict()
    for m in myMovies.values():
        if (m['statusType'] != 'suggested'):
            newSet[m["id"]] = m
    missing = max(100,len(myMovies) - len(newSet));
    count = 0
    for m in newMovies:
        if (count >= missing):
            break
        if (m["_id"] not in newSet):
            m["statusType"] = 'suggested'
            m["statusScore"] = ''
            m["id"] = m["_id"]
            newSet[m["_id"]] = m
            count = count + 1
    
        
    
    client.appdb.users.update({"_id" : userId}, {"$set" : {'profile.movies':newSet}})

# %%
 allMovies = list(client.appdb.movies.find({},{'genres':1,'title':1,'rating':1,'directors':1,'score_metascore':1,
                                              'score_rtcritics':1, 'score_imdb':1,'revenue':1,'_id':1, 'poster':1,
                                              'poster_1':1,'plot':1,'directors':1,'actors':1,'genre':1,'runtime':1,
                                              'link_imdb':1,'link_rt':1,'changed':1,'year':1,'trailer_youtube':1}))

while(1):
    job = queue.next();
    while(job):
        t0 = time.time();
        userId = job.payload["userId"]
        myMovies = getMovies(userId)
        myMoviesValue = myMovies.values();
        myPreferences = computePreferences(myMoviesValue)
        myRecommendations = findRecommendations(myPreferences, allMovies)
        updateMovies(userId, myRecommendations, myMovies)
        job.complete();
        job = queue.next();
        print (time.time() -t0)
    time.sleep(1);
# Out:
# 0.640737056732
# 0.556027889252
# 0.677837133408
# 0.868938922882
# 0.708344221115
# 0.557571172714
# 0.746071100235
# 0.636412858963
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-116-a6217cc2de96> in <module>()
#      17        job = queue.next();
#      18        print (time.time() -t0)
# ---> 19    time.sleep(1);
#
# KeyboardInterrupt:

# %%
def getMovies(userId):
    return client.appdb.users.find_one({"_id":userId},{"profile.movies" : 1})["profile"]["movies"];

allMovies = list(client.appdb.movies.find({},{'genres':1,'title':1,'rating':1,'directors':1,'score_metascore':1,
                                              'score_rtcritics':1, 'score_imdb':1,'revenue':1,'_id':1, 'poster':1,
                                              'poster_1':1,'plot':1,'directors':1,'actors':1,'genre':1}))

# %%
status = dict({
    'suggested': 0,
    'liked3': 3,
    'liked2': 2,
    'liked1': 0,
    'disliked': -2,
    'bookmarked': 1,
    'hidden': 0,
})

features = ["genre", "rating", "directors"]
featuresWeight = {'genre': 1, 'rating':1, 'directors':2}
featuresNorm = {"genre":dict(), "rating":dict(), "directors":dict()}

for feature in features:
    for m in allMovies:
        featureM = feature + 's' if feature+'s' in m else feature
        for item in m[featureM]:
            if(item not in featuresNorm[feature]):
                featuresNorm[feature][item]=0
            featuresNorm[feature][item] += 1
            

def computePreferences(userMovies):
    preferences = dict()
    for feature in features:
        preferences[feature] = dict()

    count = 0
    for movie in userMovies:
        weight = status[movie['statusType'] + str(movie['statusScore'])]
        if (weight != 0):
            count = count+1
            for feature in features:
                if (feature in movie and movie[feature]):
                    f = string.split(movie[feature],', ') #split the string to make it an array
                    if (len(f)):
                        norm = 1.0/len(f)

                        for item in f:
                            if (item not in preferences[feature]):
                                preferences[feature][item] = 0.0;
                            preferences[feature][item] += weight*norm

    for feature in preferences:
        for item in preferences[feature]:
            preferences[feature][item] /= count
    return preferences


def getMovieScore(userPreferences, movie):
    scores = dict()
    for feature in userPreferences:
        scores[feature] = 0.1
        features = movie[feature+'s'] if (feature+'s' in movie) else movie[feature] if feature in movie else []
        norm = len(features)
        for f in features:
            if (f in userPreferences[feature]):
                scores[feature] += userPreferences[feature][f]/norm
        
    
    revenue = min(10000000,max(movie['revenue'], 1000000))
    rating = 0.5
    if ('score_imdb' in movie):
        rating = movie['score_imdb'] / 10
    elif ('score_rtcritics' in movie):
        rating = movie['score_rtcritics'] / 100
    elif ('score_metascore' in movie):
        rating = movie['score_metascore'] / 100
        
    sumScore = 0
    for score in scores:
        sumScore += scores[score]*featuresWeight[score]
    
    return sumScore * revenue * rating


def findRecommendations(userGenres, allMovies):
    sort = sorted(allMovies, key=lambda s: -getMovieScore(userGenres, s) )[0:500]
    return sort[0:500]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-93f3270f19ad> in <module>()
#      16     for m in allMovies:
#      17         featureM = feature + 's' if feature+'s' in m else feature
# ---> 18         for item in m[featureM]:
#      19             if(item not in featuresNorm[feature]):
#      20                 featuresNorm[feature][item]=0
#
# KeyError: 'directors'

# %%
myMovies = getMovies('NWSbqa3DMDjXmANMq').values()

# %%
myPreferences = computePreferences(myMovies)

print myPreferences
# Out:
# {'genre': {u'Cult Movies': 0.00636904761904762, u'Performing Arts': 0.0078125, u'Sci-Fi': 0.05739583333333333, u'Crime': 0.05544146825396825, u'Romance': 0.03810515873015873, u'Animation': 0.08502645502645506, u'Music': 0.002916666666666667, u'International': 0.01250661375661376, u'Comedy': 0.10027777777777777, u'War': 0.034722222222222224, u'Horror': 0.00910218253968254, u'Science Fiction': 0.1629927248677249, u'Adventure': 0.2784292328042328, u'Thriller': 0.10225198412698412, u'Western': 0.009375, u'Mystery': 0.07944444444444446, u'Kids': 0.10577546296296299, u'Drama': 0.2850892857142858, u'Action': 0.23846395502645512, u'Classics': 0.024389880952380948, u'Documentary': 0.0008333333333333334, u'Musical': 0.0078125, u'History': 0.02673611111111111, u'Family': 0.11834490740740744, u'Special Interest': 0.004166666666666667, u'Fantasy': 0.16374669312169313, u'Suspense': 0.06850694444444445, u'Art House': 0.01250661375661376, u'Biography': 0.022291666666666664}, 'rating': {u'Unrated': 0.0125, u'R': 0.9333333333333333, u'PG': 0.4666666666666667, u'G': 0.23333333333333334, u'PG-13': 0.475}, 'directors': {u'Joel Coen': 0.00625, u'Tim Burton': 0.004166666666666667, u'Joe Russo': -0.004166666666666667, u'Ash Brannon': 0.00625, u'Tony Bancroft': 0.00625, u'Woody Allen': 0.004166666666666667, u'George Cukor': 0.0020833333333333333, u'Jennifer Lee': 0.00625, u'Angelina Jolie': 0.00625, u'Mark Andrews': 0.00625, u'Barry Levinson': 0.008333333333333333, u'Frank Darabont': 0.025, u'Darren Aronofsky': 0.004166666666666667, u'Gore Verbinski': 0.0375, u'Francis Lawrence (II)': 0.004166666666666667, u'Robert Letterman': 0.0020833333333333333, u'Ethan Coen': 0.00625, u'Marilyn Fox': 0.00625, u'James Wan': -0.008333333333333333, u'Wolfgang Becker': 0.0125, u'Francis Lawrence': 0.0125, u'Chris Sanders (III)': 0.0020833333333333333, u'Peter Berg': -0.008333333333333333, u'Nick Park': 0.0020833333333333333, u'Carlos Saldanha': 0.00625, u'Brenda Chapman': 0.00625, u'James Cameron': 0.058333333333333334, u'Edward Zwick': 0.0125, u'Michael Mann': 0.016666666666666666, u'Chris Renaud': 0.0125, u'Alan J. Abrams': 0.0020833333333333333, u'Todd Phillips': -0.008333333333333333, u'Barry Cook': 0.00625, u'Edgar Wright': 0.004166666666666667, u'Steve Norrington': 0.004166666666666667, u'Ridley Scott': 0.06666666666666667, u'Peter Docter': 0.0125, u'Milos Forman': 0.0125, u'Perce Pearce': 0.00625, u'Paul Verhoeven': 0.0125, u'Rob Marshall': 0.0125, u'Conrad Vernon': 0.0125, u'Guillermo del Toro': 0.0125, u'Tom Hooper': 0.004166666666666667, u'Tom Tykwer': -0.0020833333333333333, u'David O. Russell': 0.0125, u'Wolfgang Peterses': 0.0020833333333333333, u'Richard Linklater': 0.0125, u'Chris Columbus': 0.0375, u'Genndy Tartakovsky': 0.0125, u'Brad Bird': 0.014583333333333334, u'Clyde Geronimi': 0.0020833333333333333, u'Phil Lord': 0.0020833333333333333, u'Robert Stromberg': 0.004166666666666667, u'George Lucas': 0.025, u'James Gunn': 0.0125, u'Stephen Norrington': 0.004166666666666667, u'Sean Penn': 0.0125, u'Paul Thomas Anderson': 0.0125, u'John Frankenheimer': 0.0125, u'Mike Newell': 0.0125, u'David Fincher': 0.03333333333333333, u'Eric Goldberg': 0.00625, u'Jennifer Yuh': 0.004166666666666667, u'J.J. Abrams': 0.00625, u'Rob Letterman': 0.0020833333333333333, u'Peter Hastings': 0.00625, u'Alan Taylor': 0.008333333333333333, u'Dan Scanlon': 0.004166666666666667, u'Lee Unkrich': 0.01875, u'Gus Van Sant': 0.0125, u'Doug Liman': 0.0125, u'George Miller': 0.0125, u'Jonathan Demme': 0.0125, u'Ralph Zondag': 0.00625, u'Jean-Jacques Annaud': 0.0125, u'Andrew Stanton': 0.025, u'Steve Box': 0.0020833333333333333, u'Robert Zemeckis': 0.04583333333333333, u'Joss Whedon': 0.008333333333333333, u'Jon Favreau': 0.025, u'Ron Howard': 0.004166666666666667, u'Michel Gondry': 0.0125, u'Mel Gibson': 0.0125, u'Pedro Almodovar': 0.0125, u'Matt Reeves': 0.008333333333333333, u'Larry Wachowski': 0.016666666666666666, u'Ron Clements': 0.00625, u'Matthew Vaughn': 0.027083333333333334, u ...

# %%
findRecommendations(myPreferences, allMovies)
# Out:
# [{u'_id': u'eawuukCn9H8tHSo6X',
#   u'actors': u'Macintalk, Ben Burtt, Elissa Knight, Jeff Garlin, Fred Willard',
#   u'directors': u'Andrew Stanton',
#   u'genre': u'Family, Science Fiction, Romance, Fantasy, Animation, Adventure, Action',
#   u'genres': [u'Family',
#    u'Science Fiction',
#    u'Romance',
#    u'Fantasy',
#    u'Animation',
#    u'Adventure',
#    u'Action'],
#   u'plot': u"WALL-E is the last robot left on an Earth that has been overrun with garbage and all humans have fled to outer space. For 700 years he has continued to try and clean up the mess, but has developed some rather interesting human-like qualities. When a ship arrives with a sleek new type of robot, Wall-E thinks he's finally found a friend and stows away on the ship when it leaves.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTczOTA3MzY2N15BMl5BanBnXkFtZTcwOTYwNjE2MQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/4qOKgcDcB0SojUIg2syzor1FeL7.jpg',
#   u'rating': u'G',
#   u'revenue': 521311860,
#   u'score_imdb': 8.5,
#   u'score_metascore': 94,
#   u'score_rtcritics': 96,
#   u'title': u'WALL\xb7E'},
#  {u'_id': u'qQSyCCibs4eBzcnmp',
#   u'actors': u'Emily Hahn, Tom Hanks, Tim Allen, Joan Cusack, Ned Beatty',
#   u'directors': u'Lee Unkrich',
#   u'genre': u'Kids, Family, Fantasy, Science Fiction, Animation, Adventure, Comedy',
#   u'genres': [u'Kids',
#    u'Family',
#    u'Fantasy',
#    u'Science Fiction',
#    u'Animation',
#    u'Adventure',
#    u'Comedy'],
#   u'plot': u"Woody, Buzz, and the rest of Andy's toys haven't been played with in years. With Andy about to go to college, the gang find themselves accidentally left at a nefarious day care center. The toys must band together to escape and return home to Andy.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTgxOTY4Mjc0MF5BMl5BanBnXkFtZTcwNTA4MDQyMw@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/tOwAAVeL1p3ls9dhOBo45ElodU3.jpg',
#   u'rating': u'G',
#   u'revenue': 1063171911,
#   u'score_imdb': 8.4,
#   u'score_metascore': 92,
#   u'score_rtcritics': 99,
#   u'title': u'Toy Story 3'},
#  {u'_id': u'rJs6h7HSwvz7ri3tx',
#   u'actors': u'Greg Berg, Kendall Cunningham, Sherry Lynn, Scott McAfee, Patrick Pinney',
#   u'directors': u'John Lasseter',
#   u'genre': u'Kids, Family, Fantasy, Science Fiction, Animation, Adventure, Comedy',
#   u'genres': [u'Kids',
#    u'Family',
#    u'Fantasy',
#    u'Science Fiction',
#    u'Animation',
#    u'Adventure',
#    u'Comedy'],
#   u'plot': u'Woody the cowboy is young Andy\u2019s favorite toy. Yet this changes when Andy get the new super toy Buzz Lightyear for his birthday. Now that Woody is no longer number one he plans his revenge on Buzz. Toy Story is a milestone in film history for being the first feature film to use entirely computer animation.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTgwMjI4MzU5N15BMl5BanBnXkFtZTcwMTMyNTk3OA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/agy8DheVu5zpQFbXfAdvYivF2FU.jpg',
#   u'rating': u'G',
#   u'revenue': 361958736,
#   u'score_imdb': 8.3,
#   u'score_metascore': 92,
#   u'score_rtcritics': 100,
#   u'title': u'Toy Story'},
#  {u'_id': u'nG2i3iXGQLMhR7TAB',
#   u'actors': u'Harrison Ford II, Karen Allen, Paul Freeman, Wolf Kahler, Ronald Lacey',
#   u'directors': u'Steven Spielberg',
#   u'genre': u'Action, Adventure',
#   u'genres': [u'Action', u'Adventure'],
#   u'plot': u'When Dr. Indiana Jones \u2013 the tweed-suited professor who just happens to be a celebrated archaeologist \u2013 is hired by the government to locate the legendary Ark of the Covenant, he finds himself up against the entire Nazi regime.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjA0ODEzMTc1Nl5BMl5BanBnXkFtZTcwODM2MjAxNA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/qB4BK9ddEbuka8G38AlnXBDDwt3.jpg',
#   u'rating': u'PG',
#   u'revenue': 383000000,
#   u'score_imdb': 8.6,
#   u'score_metascore': 90,
#   u'score_rtcritics': 95,
#   u'title': u'Raiders of the Lost Ark'},
#  {u'_id': u'7N8S8bz3i6TqgWgop',
#   u'actors': u'Alison Janney, Nicolas Bird, Albert Brooks, Ellen DeGeneres, Alexander Gould',
#   u'directors': u'Andrew Stanton, Lee Unkrich',
#   u'genre': u'Comedy, Kids, Animation, Adventure, Family',
#   u'genres': [u'Comedy', u'Kids', u'Animation', u'Adventure', u'Family'],
#   u'plot': u"A tale which follows the comedic and eventful journeys of two fish, the fretful Marlin and his young son Nemo, who are separated from each other in the Great Barrier Reef when Nemo is unexpectedly taken from his home and thrust into a fish tank in a dentist's office overlooking Sydney Harbor. Buoyed by the companionship of a friendly but forgetful fish named Dory, the overly cautious Marlin embarks on a dangerous trek and finds himself the unlikely hero of an epic journey to rescue his son.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTY1MTg1NDAxOV5BMl5BanBnXkFtZTcwMjg1MDI5Nw@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/zjqInUwldOBa0q07fOyohYCWxWX.jpg',
#   u'rating': u'G',
#   u'revenue': 864625978,
#   u'score_imdb': 8.2,
#   u'score_metascore': 90,
#   u'score_rtcritics': 99,
#   u'title': u'Finding Nemo'},
#  {u'_id': u'NoRASqBeaEMWhWeFm',
#   u'actors': u'Jason Weaver, David McCharen, Cathy Cavadini, Judi M. Durand, Matthew Broderick',
#   u'directors': u'Roger Allers, Rob Minkoff',
#   u'genre': u'Performing Arts, Kids, Family, Drama, Animation, Adventure, Action, Musical',
#   u'genres': [u'Performing Arts',
#    u'Kids',
#    u'Family',
#    u'Drama',
#    u'Animation',
#    u'Adventure',
#    u'Action',
#    u'Musical'],
#   u'plot': u"A young lion cub named Simba can't wait to be king. But his uncle craves the title for himself and will stop at nothing to get it.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjEyMzgwNTUzMl5BMl5BanBnXkFtZTcwNTMxMzM3Ng@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/bKPtXn9n4M4s8vvZrbw40mYsefB.jpg',
#   u'rating': u'G',
#   u'revenue': 788241776,
#   u'score_imdb': 8.5,
#   u'score_metascore': 83,
#   u'score_rtcritics': 90,
#   u'title': u'The Lion King'},
#  {u'_id': u'tnB7GWK7hXKpamZ43',
#   u'actors': u'Kay Panabaker, Rodger Bumpass, John Goodman, Billy Crystal, Mary Gibbs',
#   u'directors': u'Peter Docter, Pete Docter',
#   u'genre': u'Kids, Family, Fantasy, Science Fiction, Animation, Adventure, Comedy',
#   u'genres': [u'Kids',
#    u'Family',
#    u'Fantasy',
#    u'Science Fiction',
#    u'Animation',
#    u'Adventure',
#    u'Comedy'],
#   u'plot': u"James Sullivan and Mike Wazowski are monsters, they earn their living scaring children and are the best in the business... even though they're more afraid of the children than they are of them. When a child accidentally enters their world, James and Mike suddenly find that kids are not to be afraid of and they uncover a conspiracy that could threaten all children across the world.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTY1NTI0ODUyOF5BMl5BanBnXkFtZTgwNTEyNjQ0MDE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/93Y9BGx8blzmZOPSoivkFfaifqU.jpg',
#   u'rating': u'G',
#   u'revenue': 558523378,
#   u'score_imdb': 8.1,
#   u'score_metascore': 78,
#   u'score_rtcritics': 96,
#   u'title': u'Monsters, Inc.'},
#  {u'_id': u'6E5Bj3KRC7K4bSxAw',
#   u'actors': u'Wayne Knights, Tom Hanks, Tim Allen, Joan Cusack, Kelsey Grammer',
#   u'directors': u'Ash Brannon, John Lasseter',
#   u'genre': u'Kids, Family, Fantasy, Science Fiction, Animation, Adventure, Comedy',
#   u'genres': [u'Kids',
#    u'Family',
#    u'Fantasy',
#    u'Science Fiction',
#    u'Animation',
#    u'Adventure',
#    u'Comedy'],
#   u'plot': u'During a garage sale Andy\u2019s mother sells some of Andy\u2019s old things including his favorite toy Woody to a collector. Buzz Lightyear and the other toys begin a reckless mission to save their friend. The sequel to the revolutionary computer animated feature film Toy Story.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTQ0OTU0NTcyNl5BMl5BanBnXkFtZTcwOTk5Mjc4OA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/gd12nM0VnrgbaUmZDjte4oBedGZ.jpg',
#   u'rating': u'G',
#   u'revenue': 485015179,
#   u'score_imdb': 7.9,
#   u'score_metascore': 88,
#   u'score_rtcritics': 100,
#   u'title': u'Toy Story 2'},
#  {u'_id': u'Q3mehsai8cCePgLdn',
#   u'actors': u'Keir Dullea, Gary Lockwood, William Sylvester, Daniel Richter, Leonard Rossiter',
#   u'directors': u'Stanley Kubrick',
#   u'genre': u'Mystery, Sci-Fi, Fantasy, Science Fiction, Adventure, Classics',
#   u'genres': [u'Mystery',
#    u'Sci-Fi',
#    u'Fantasy',
#    u'Science Fiction',
#    u'Adventure',
#    u'Classics'],
#   u'plot': u'Humanity finds a mysterious, obviously artificial, object buried beneath the Lunar surface and, with the intelligent computer H.A.L. 9000, sets off on a quest.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNDYyMDgxNDQ5Nl5BMl5BanBnXkFtZTcwMjc1ODg3OA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/eDiexVN4nO3ZdDZCDMiJOX5fQ5r.jpg',
#   u'rating': u'G',
#   u'revenue': 56715371,
#   u'score_imdb': 8.3,
#   u'score_metascore': 86,
#   u'score_rtcritics': 96,
#   u'title': u'2001: A Space Odyssey'},
#  {u'_id': u'9JuC44k2GoTnjtd57',
#   u'actors': u'Keanu Reeves, Laurence Fishburne, Carrie-Anne Moss, Joe Pantoliano, Hugo Weaving',
#   u'directors': u'The Wachowski Brothers, Larry Wachowski',
#   u'genre': u'Sci-Fi, Fantasy, Science Fiction, Adventure, Action, Thriller',
#   u'genres': [u'Sci-Fi',
#    u'Fantasy',
#    u'Science Fiction',
#    u'Adventure',
#    u'Action',
#    u'Thriller'],
#   u'plot': u'Thomas A. Anderson is a man living two lives. By day he is an average computer programmer and by night a malevolent hacker known as Neo, who finds himself targeted by the police when he is contacted by Morpheus, a legendary computer hacker, who reveals the shocking truth about our reality.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTkxNDYxOTA4M15BMl5BanBnXkFtZTgwNTk0NzQxMTE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/ZPMhHXEhYB33YoTZZNNmezth0V.jpg',
#   u'rating': u'R',
#   u'revenue': 463517383,
#   u'score_imdb': 8.7,
#   u'score_metascore': 73,
#   u'score_rtcritics': 87,
#   u'title': u'The Matrix'},
#  {u'_id': u'Yh2NZJqRLvcTedTCk',
#   u'actors': u'Russell Crowe, Joaquin Phoenix, Connie Nielsen, Oliver Reed, Richard Harris',
#   u'directors': u'Ridley Scott',
#   u'genre': u'Action, Drama, Classics, Adventure',
#   u'genres': [u'Action', u'Drama', u'Classics', u'Adventure'],
#   u'plot': u"Gladiator is an epic film of love, death and betrayal set in the Roman Empire. General Maximus' success in battle earns the favour of an elderly Emperor at the expense of the Emperor's son. In a fit of jealous rage the son slays his father before turning his anger towards Maximus. Now reduced to a slave, his family dead, Maximus must fight as a gladiator to gain his freedom, and his revenge.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTgwMzQzNTQ1Ml5BMl5BanBnXkFtZTgwMDY2NTYxMTE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/6WBIzCgmDCYrqh64yDREGeDk9d3.jpg',
#   u'rating': u'R',
#   u'revenue': 457640427,
#   u'score_imdb': 8.5,
#   u'score_metascore': 64,
#   u'score_rtcritics': 76,
#   u'title': u'Gladiator'},
#  {u'_id': u'RsQNk4D4CC3Yz4pta',
#   u'actors': u'Brad Pitt, Edward Norton, Helena Bonham Carter, Meat Loaf, Jared Leto',
#   u'directors': u'David Fincher',
#   u'genre': u'Drama, Comedy',
#   u'genres': [u'Drama', u'Comedy'],
#   u'plot': u'A ticking-time-bomb insomniac and a slippery soap salesman channel primal male aggression into a shocking new form of therapy. Their concept catches on, with underground "fight clubs" forming in every town, until an eccentric gets in the way and ignites an out-of-control spiral toward oblivion.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjIwNTYzMzE1M15BMl5BanBnXkFtZTcwOTE5Mzg3OA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/2lECpi35Hnbpa4y46JX0aY3AWTy.jpg',
#   u'rating': u'R',
#   u'revenue': 100853753,
#   u'score_imdb': 8.9,
#   u'score_metascore': 66,
#   u'score_rtcritics': 80,
#   u'title': u'Fight Club'},
#  {u'_id': u'LeG4ZMzjqxSJ5AWdK',
#   u'actors': u'Martin Sheen, Marlon Brando, Robert Duvall, Frederic Forrest, Sam Bottoms',
#   u'directors': u'Francis Ford Coppola',
#   u'genre': u'Drama, Action, War, Adventure',
#   u'genres': [u'Drama', u'Action', u'War', u'Adventure'],
#   u'plot': u'At the height of the Vietnam war, Captain Benjamin Willard is sent on a dangerous mission that, officially, "does not exist, nor will it ever exist." His goal is to locate - and eliminate - a mysterious Green Beret Colonel named Walter Kurtz, who has been leading his personal army on illegal guerrilla missions into enemy territory.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTcyMzQ5NDM4OV5BMl5BanBnXkFtZTcwODUwNDg3OA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/l8dn7rKbjP36PtHsViHGpzf5ey7.jpg',
#   u'rating': u'R',
#   u'revenue': 83471511,
#   u'score_imdb': 8.5,
#   u'score_metascore': 90,
#   u'score_rtcritics': 99,
#   u'title': u'Apocalypse Now'},
#  {u'_id': u'2c9iirWCFxvXmPZ3z',
#   u'actors': u'Helena Bonham Carter, Peter Sallis, Ralph Fiennes, John Thomson, Peter Kay',
#   u'directors': u'Steve Box, Nick Park',
#   u'genre': u'Kids, Family, Animation, Adventure, Action, Comedy',
#   u'genres': [u'Kids',
#    u'Family',
#    u'Animation',
#    u'Adventure',
#    u'Action',
#    u'Comedy'],
#   u'plot': u"Cheese-loving eccentric Wallace and his cunning canine pal, Gromit, investigate a mystery in Nick Park's animated adventure, in which the lovable inventor and his intrepid pup run a business ridding the town of garden pests. Using only humane methods that turn their home into a halfway house for evicted vermin, the pair stumble upon a mystery involving a voracious vegetarian monster that threatens to ruin the annual veggie-growing contest.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTk1NzIwNTM1NV5BMl5BanBnXkFtZTcwMDA1NzkyMw@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/tLryx0x9TDV5rifA9W8yUvDZFHB.jpg',
#   u'rating': u'G',
#   u'revenue': 192452832,
#   u'score_imdb': 7.6,
#   u'score_metascore': 87,
#   u'score_rtcritics': 95,
#   u'title': u'Wallace & Gromit: The Curse of the Were-Rabbit'},
#  {u'_id': u'LvRysQcg2JjFGLoNb',
#   u'actors': u'Miguel Ferrer, Soon-Teck Oh, Miriam Margolyes, James Shigeta, Freda Foh Shen',
#   u'directors': u'Barry Cook, Tony Bancroft',
#   u'genre': u'Action, Kids, Animation, Adventure, Family',
#   u'genres': [u'Action', u'Kids', u'Animation', u'Adventure', u'Family'],
#   u'plot': u'A tomboyish girl disguises herself as a young man so she can fight with the Imperial Chinese Army against the invading Huns. With help from wise-cracking dragon Mushu, Mulan just might save her country -- and win the heart of handsome Captain Li Shang.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTIwNjY4NDU2NF5BMl5BanBnXkFtZTcwMzM0OTUyMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/ztD0iLfeyESQZV95GwPeSE3Uyqn.jpg',
#   u'rating': u'G',
#   u'revenue': 304320254,
#   u'score_imdb': 7.5,
#   u'score_metascore': 71,
#   u'score_rtcritics': 86,
#   u'title': u'Mulan'},
#  {u'_id': u'taRQjQRDgzneNzosX',
#   u'actors': u'Patton Oswalt, Ian Holm, Lou Romano, Brian Dennehy, Peter Sohn',
#   u'directors': u'Brad Bird, Jan Pinkava',
#   u'genre': u'Comedy, Kids, Animation, Family',
#   u'genres': [u'Comedy', u'Kids', u'Animation', u'Family'],
#   u'plot': u"In one of Paris' finest restaurants, Remy, a determined young rat, dreams of becoming a renowned French chef. Torn between his family's wishes and his true calling. Remy and his pal Linguini set in motion a hilarious chain of events that turns the City of Lights upside down.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTMzODU0NTkxMF5BMl5BanBnXkFtZTcwMjQ4MzMzMw@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/wbG9OoWlkZ7QRyxfvpjdWUbfREX.jpg',
#   u'rating': u'G',
#   u'revenue': 623722164,
#   u'score_imdb': 8,
#   u'score_metascore': 96,
#   u'score_rtcritics': 96,
#   u'title': u'Ratatouille'},
#  {u'_id': u'6KzEM64jgqKz3q8L4',
#   u'actors': u'Charlton Heston, Jack Hawkins, Stephen Boyd, Haya Harareet, Martha Scott',
#   u'directors': u'William Wyler',
#   u'genre': u'Romance, Kids, Family, Drama, Adventure, Action, Classics, History',
#   u'genres': [u'Romance',
#    u'Kids',
#    u'Family',
#    u'Drama',
#    u'Adventure',
#    u'Action',
#    u'Classics',
#    u'History'],
#   u'plot': u"Ben-Hur is a 1959 epic film directed by William Wyler, the third film version of Lew Wallace's 1880 novel Ben-Hur: A Tale of the Christ. It premiered at Loew's State Theatre in New York City on November 18, 1959. The film went on to win a record of eleven Academy Awards, including Best Picture, a feat equaled only by Titanic in 1998 and The Lord of the Rings: The Return of the King in 2004. It was also the last film to win the Oscar for both Best Actor and Best Supporting Actor, until nearly 44 years later when Mystic River achieved the same feat.The movie revolves around a Jewish prince who is betrayed and sent into slavery by a Roman friend and how he regains his freedom and comes back for revenge.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNjg2NjA3NDY2OV5BMl5BanBnXkFtZTgwNzE3NTkxMTE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/cNSBgQgJx2yXxYlIyWFhWz2F377.jpg',
#   u'rating': u'G',
#   u'revenue': 90000000,
#   u'score_imdb': 8.1,
#   u'score_rtcritics': 87,
#   u'title': u'Ben-Hur'},
#  {u'_id': u'REZ9cguBy4gp9RPBc',
#   u'actors': u'Emile Hirsch, Marcia Gay Harden, William Hurt, Catherine Keener, Hal Holbrook',
#   u'directors': u'Sean Penn',
#   u'genre': u'Drama, Action, Adventure, Biography',
#   u'genres': [u'Drama', u'Action', u'Adventure', u'Biography'],
#   u'plot': u'Based on a true story. After graduating from Emory University in 1992, top student and athlete Christopher McCandless abandoned his possessions, gave his entire $24,000 savings account to charity and hitchhiked to Alaska to live in the wilderness. Along the way, Christopher encounters a series of characters who shape his life.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTAwNDEyODU1MjheQTJeQWpwZ15BbWU2MDc3NDQwNw@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/lHyYgaocXR6KcJLxVmxZDj115hH.jpg',
#   u'rating': u'R',
#   u'revenue': 37682065,
#   u'score_imdb': 8.2,
#   u'score_metascore': 73,
#   u'score_rtcritics': 82,
#   u'title': u'Into the Wild'},
#  {u'_id': u'Lr7w3ap8RAMXbFYDq',
#   u'actors': u'Arnold Schwarzenegger, Linda Hamilton, Edward Furlong, Robert Patrick, Earl Boen',
#   u'directors': u'James Cameron',
#   u'genre': u'Sci-Fi, Fantasy, Science Fiction, Adventure, Action, Thriller',
#   u'genres': [u'Sci-Fi',
#    u'Fantasy',
#    u'Science Fiction',
#    u'Adventure',
#    u'Action',
#    u'Thriller'],
#   u'plot': u'Nearly 10 years have passed since Sarah Connor was targeted for termination by a cyborg from the future. Now her son, John, the future leader of the resistance, is the target for a newer, more deadly terminator. Once again, the resistance has managed to send a protector back to attempt to save John and his mother Sarah.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTg5NzUwMDU5NF5BMl5BanBnXkFtZTcwMjk2MDA4Mg@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/2y4dmgWYRMYXdD1UyJVcn2HSd1D.jpg',
#   u'rating': u'R',
#   u'revenue': 520000000,
#   u'score_imdb': 8.5,
#   u'score_metascore': 68,
#   u'score_rtcritics': 92,
#   u'title': u'Terminator 2: Judgment Day'},
#  {u'_id': u'XNzbAABeqcPyqftcn',
#   u'actors': u"Matthew Modine, Vincent D'Onofrio, Arliss Howard, Jon Stafford, John Terry",
#   u'directors': u'Stanley Kubrick, Francesca Cima',
#   u'genre': u'Drama, Action, War, Adventure',
#   u'genres': [u'Drama', u'Action', u'War', u'Adventure'],
#   u'plot': u'A pragmatic U.S. Marine observes the dehumanizing effects the U.S.-Vietnam War has on his fellow recruits from their brutal boot camp training to the bloody street fighting in Hue.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjA4NzY4ODk4Nl5BMl5BanBnXkFtZTgwOTcxNTYxMTE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/vM5Pkp4L6nB9TzNARhrToOE11IX.jpg',
#   u'rating': u'R',
#   u'revenue': 46357676,
#   u'score_imdb': 8.4,
#   u'score_metascore': 78,
#   u'score_rtcritics': 94,
#   u'title': u'Full Metal Jacket'},
#  {u'_id': u'yCm6pf2NTxumw9HB6',
#   u'actors': u'Robin Williams, Scott Weinger, Linda Larkin, Jonathan Freeman, Frank Welker',
#   u'directors': u'John Musker, Ron Clements',
#   u'genre': u'Performing Arts, Kids, Family, Romance, Fantasy, Animation, Adventure, Action, Comedy, Musical',
#   u'genres': [u'Performing Arts',
#    u'Kids',
#    u'Family',
#    u'Romance',
#    u'Fantasy',
#    u'Animation',
#    u'Adventure',
#    u'Action',
#    u'Comedy',
#    u'Musical'],
#   u'plot': u'Princess Jasmine grows tired of being forced to remain in the palace and she sneaks out into the marketplace  in disguise where she meets street-urchin Aladdin and the two fall in love, although she may only marry a prince. After being thrown in jail, Aladdin and becomes embroiled in a plot to find a mysterious lamp with which the evil Jafar hopes to rule the land.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNTI4ODQ1MzAzNV5BMl5BanBnXkFtZTgwMzU4NzMxMDE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/oA2AY6adBYrHSrvMQSfZ14yA0HA.jpg',
#   u'rating': u'G',
#   u'revenue': 504050219,
#   u'score_imdb': 8,
#   u'score_rtcritics': 94,
#   u'title': u'Aladdin'},
#  {u'_id': u'7BCK5PeNz2r5rEX6o',
#   u'actors': u'Fay Wray, Robert Armstrong, Bruce Cabot, Sam Hardy, Frank Reicher',
#   u'directors': u'Ernest B. Schoedsack, Merian C. Cooper',
#   u'genre': u'Horror, Drama, Fantasy, Adventure, Action, Classics, Thriller',
#   u'genres': [u'Horror',
#    u'Drama',
#    u'Fantasy',
#    u'Adventure',
#    u'Action',
#    u'Classics',
#    u'Thriller'],
#   u'plot': u'An adventure film about a film crew in search of a monster on a remote island. The crew finds King Kong and decides to take him back to New York as a money making spectacle. The film is a masterpiece of Stop-Motion in filmmaking history and inspired a line of King Kong films.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BODM0MTEyMjQxOF5BMl5BanBnXkFtZTgwNzYwNTk1MjE@._V1._CR8.883331298828125,6.5333404541015625,344,488_SY132_CR2,0,89,132_AL_.jpg_V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/b1FzD0WxnfhkIbjxwFOKJHUuEsH.jpg',
#   u'rating': u'G',
#   u'revenue': 10000000,
#   u'score_imdb': 8,
#   u'score_rtcritics': 98,
#   u'title': u'King Kong'},
#  {u'_id': u'9L8agboQSgEHkCtcL',
#   u'actors': u'Michael Keaton, Lindsay Duncan, Zach Galifianakis, Edward Norton, Andrea Riseborough',
#   u'directors': u'Alejandro Gonzalez Inarritu',
#   u'genre': u'Drama, Comedy',
#   u'genres': [u'Drama', u'Comedy'],
#   u'plot': u'A fading actor (Michael Keaton) best known for his portrayal of a popular superhero attempts to mount a comeback by appearing in a Broadway play. As opening night approaches, his attempts to become more altruistic, rebuild his career, and reconnect with friends and family prove more difficult than expected. Lindsay Duncan, Zach Galifianakis, and Edward Norton co-star in this black comedy from Biutiful director Alejandro Gonz\xe1lez I\xf1\xe1rritu.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BODAzNDMxMzAxOV5BMl5BanBnXkFtZTgwMDMxMjA4MjE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/6yjQoECOKuXzQ14Bnf68WzTIotJ.jpg',
#   u'rating': u'R',
#   u'revenue': 21822413,
#   u'score_imdb': 8.7,
#   u'score_metascore': 89,
#   u'score_rtcritics': 93,
#   u'title': u'Birdman'},
#  {u'_id': u'zBbjr4n67g3GwYEz2',
#   u'actors': u'Charlton Heston, Roddy McDowall, Kim Hunter, Maurice Evans, James Whitmore',
#   u'directors': u'Franklin J. Schaffner',
#   u'genre': u'Mystery, Sci-Fi, Fantasy, Science Fiction, Adventure, Classics',
#   u'genres': [u'Mystery',
#    u'Sci-Fi',
#    u'Fantasy',
#    u'Science Fiction',
#    u'Adventure',
#    u'Classics'],
#   u'plot': u'Taylor and two other astronauts come out of deep hibernation to find that their ship has crashed. Escaping with little more than clothes they find that they have landed on a planet where men are pre-lingual and uncivilized while apes have learned speech and technology. Taylor is captured and taken to the city of the apes after damaging his throat so that he is silent and cannot communicate with the apes.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTg0NjUwMzg5NF5BMl5BanBnXkFtZTgwNDQ0NjcwMTE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/ktS3v2OfBouSiDDA3tQsrjidt5i.jpg',
#   u'rating': u'G',
#   u'revenue': 33395426,
#   u'score_imdb': 8,
#   u'score_rtcritics': 89,
#   u'title': u'Planet of the Apes'},
#  {u'_id': u'hMF8Hfqo6LcGYgrtS',
#   u'actors': u'The Muppets, Michael Caine, Rob Tygner, Karen Prell, Jessica Fox',
#   u'directors': u'Brian Henson',
#   u'genre': u'Kids, Family, Fantasy, Drama, Science Fiction, Comedy',
#   u'genres': [u'Kids',
#    u'Family',
#    u'Fantasy',
#    u'Drama',
#    u'Science Fiction',
#    u'Comedy'],
#   u'plot': u'A retelling of the classic Dickens tale of Ebenezer Scrooge, miser extraordinaire. He is held accountable for his dastardly ways during night-time visitations by the Ghosts of Christmas Past, Present, and future.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjA3NzE5NzczOV5BMl5BanBnXkFtZTgwNzc1Njc1MzE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/fe4nLJkDNXhyuMnrZ60MfoSpPes.jpg',
#   u'rating': u'G',
#   u'revenue': 27281507,
#   u'score_imdb': 7.7,
#   u'score_rtcritics': 69,
#   u'title': u'The Muppet Christmas Carol'},
#  {u'_id': u'KjXvTKg3Y5Q9Qzk2G',
#   u'actors': u'Olivia Coleman, Nick Frost, Jim Broadbent, Steve Coogan, Edward Woodward',
#   u'directors': u'Edgar Wright, Pegg and Edgar Wright ("Shaun of the Dead")',
#   u'genre': u'Drama, Action, Comedy, Adventure',
#   u'genres': [u'Drama', u'Action', u'Comedy', u'Adventure'],
#   u'plot': u"Top London cop, PC Nicholas Angel is good. Too good. And to stop the rest of his team looking bad, he is reassigned to the quiet town of Sandford. Paired with simple country cop Danny, everything seems quiet until two actors are found decapitated. It is addressed as an accident, but Angel isn't going to accept that, especially when more and more people turn up dead.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTIxODg2NDU1MF5BMl5BanBnXkFtZTcwOTc3MDM0MQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/5Jx6s6VXnunh8wCLgR0YgjwSgjh.jpg',
#   u'rating': u'R',
#   u'revenue': 79536889,
#   u'score_imdb': 7.9,
#   u'score_metascore': 81,
#   u'score_rtcritics': 91,
#   u'title': u'Hot Fuzz'},
#  {u'_id': u'NTfAKxFR8h7aruQky',
#   u'actors': u'Helen Mirren, Sean Hayes, Alfred Molina, Tyler Labine, Nathan Fillion',
#   u'directors': u'Dan Scanlon',
#   u'genre': u'Kids, Family, Fantasy, Science Fiction, Animation, Adventure, Action, Comedy',
#   u'genres': [u'Kids',
#    u'Family',
#    u'Fantasy',
#    u'Science Fiction',
#    u'Animation',
#    u'Adventure',
#    u'Action',
#    u'Comedy'],
#   u'plot': u"A look at the relationship between Mike and Sulley during their days at Monsters University \u2014 when they weren't necessarily the best of friends.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTUyODgwMDU3M15BMl5BanBnXkFtZTcwOTM4MjcxOQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/flXrt9Dh0Tki6zOgX0TOq63KpG8.jpg',
#   u'rating': u'G',
#   u'revenue': 743559607,
#   u'score_imdb': 7.4,
#   u'score_metascore': 65,
#   u'score_rtcritics': 78,
#   u'title': u'Monsters University'},
#  {u'_id': u'mebiEKMTusxoTJwjy',
#   u'actors': u'Mickey Mouse, Wayne Allwine, Will Ryan, Patricia Parris, Clarence Nash',
#   u'directors': u'Burny Mattinson',
#   u'genre': u'Fantasy, Kids, Short, Animation, Family',
#   u'genres': [u'Fantasy', u'Kids', u'Short', u'Animation', u'Family'],
#   u'plot': u"It is an adaptation of the Charles Dickens classic A Christmas Carol, featuring Scrooge McDuck as his namesake and inspiration Ebenezer Scrooge and Mickey Mouse as Bob Cratchit. This film was based on a 1972 audio musical entitled Disney's A Christmas Carol. It is a twenty-four minute animated short film produced by Walt Disney Productions as an accompaniment to a re-release of The Rescuers.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjEzNTM4NzE2N15BMl5BanBnXkFtZTcwODM3ODcxMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/b5bOnImybMdWNA415PXFjMWlsi7.jpg',
#   u'rating': u'G',
#   u'revenue': 21000000,
#   u'score_imdb': 8,
#   u'title': u"Mickey's Christmas Carol"},
#  {u'_id': u'99ise8FrW7mPcikna',
#   u'actors': u'Tom Hanks, Tom Sizemore, Matt Damon, Edward Burns, Barry Pepper',
#   u'directors': u'Steven Spielberg',
#   u'genre': u'Action, Drama, History, War, Adventure',
#   u'genres': [u'Action', u'Drama', u'History', u'War', u'Adventure'],
#   u'plot': u'As U.S. troops storm the beaches of Normandy, three brothers lie dead on the battlefield, with a fourth trapped behind enemy lines. Ranger captain John Miller and seven men are tasked with penetrating German-held territory and bringing the boy home.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNjczODkxNTAxN15BMl5BanBnXkFtZTcwMTcwNjUxMw@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/gc7IN6bWNaWXv4vI6cxSmeB7PeO.jpg',
#   u'rating': u'R',
#   u'revenue': 481840909,
#   u'score_imdb': 8.6,
#   u'score_metascore': 90,
#   u'score_rtcritics': 93,
#   u'title': u'Saving Private Ryan'},
#  {u'_id': u'TRhtscugfMkYgHikw',
#   u'actors': u'Yuria Nara, Hiroki Doi, Tomoko Yamaguchi, Kazushige Nagashima, George Tokoro',
#   u'directors': u'Hayao Miyazaki',
#   u'genre': u'Kids, Family, Fantasy, Science Fiction, Animation, Adventure, Action, International, Art House',
#   u'genres': [u'Kids',
#    u'Family',
#    u'Fantasy',
#    u'Science Fiction',
#    u'Animation',
#    u'Adventure',
#    u'Action',
#    u'International',
#    u'Art House'],
#   u'plot': u"The son of a sailor, 5-year old Sosuke lives a quiet life on an oceanside cliff with his mother Lisa. One fateful day, he finds a beautiful goldfish trapped in a bottle on the beach and upon rescuing her, names her Ponyo. But she is no ordinary goldfish. The daughter of a masterful wizard and a sea goddess, Ponyo uses her father's magic to transform herself into a young girl and quickly falls in love with Sosuke, but the use of such powerful sorcery causes a dangerous imbalance in the world. As the moon steadily draws nearer to the earth and Ponyo's father sends the ocean's mighty waves to find his daughter, the two children embark on an adventure of a lifetime to save the world and fulfill Ponyo's dreams of becoming human.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjA5NzkxNTg2MF5BMl5BanBnXkFtZTcwMTA3MjU1Mg@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/tg7Z7rCzncljHlAONch3dmpxy4s.jpg',
#   u'rating': u'G',
#   u'revenue': 187479518,
#   u'score_imdb': 7.7,
#   u'score_metascore': 86,
#   u'score_rtcritics': 92,
#   u'title': u'Ponyo'},
#  {u'_id': u'oz2XdDwH9wfJDJdB7',
#   u'actors': u'Sophie Marceau, Patrick McGoohan, Catherine McCormack, Brendan Gleeson, James Cosmo',
#   u'directors': u'Mel Gibson',
#   u'genre': u'Action, Drama, Classics, Adventure, Biography',
#   u'genres': [u'Action', u'Drama', u'Classics', u'Adventure', u'Biography'],
#   u'plot': u"Enraged at the slaughter of Murron, his new bride and childhood love, legendary Scottish warrior William Wallace slays a platoon of the local English lord's soldiers. This leads the village to revolt and, eventually, the entire country to rise up against English rule.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNjA4ODYxMDU3Nl5BMl5BanBnXkFtZTcwMzkzMTk3OA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/2qAgGeYdLjelOEqjW9FYvPHpplC.jpg',
#   u'rating': u'R',
#   u'revenue': 210000000,
#   u'score_imdb': 8.4,
#   u'score_metascore': 68,
#   u'score_rtcritics': 78,
#   u'title': u'Braveheart'},
#  {u'_id': u'KMNiwZrh5SK3BZth6',
#   u'actors': u'Candy Hutson, Will Ryan, Bill Erwin, Burke Barnes, Gabriel Damon',
#   u'directors': u'Don Bluth',
#   u'genre': u'Kids, Family, Fantasy, Science Fiction, Animation, Adventure, Action',
#   u'genres': [u'Kids',
#    u'Family',
#    u'Fantasy',
#    u'Science Fiction',
#    u'Animation',
#    u'Adventure',
#    u'Action'],
#   u'plot': u'An orphaned brontosaurus named Littlefoot sets off in search of the legendary Great Valley. A land of lush vegetation where the dinosaurs can thrive and live in peace. Along the way he meets four other young dinosaurs, each onea different species, and they encounter several obstacles as they learn to worktogether in order to survive.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BOTkyNjQ0MDA1OV5BMl5BanBnXkFtZTcwMDkyMTYyMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/64Kq57TiQCfJjMORxNS1lUAnFoL.jpg',
#   u'rating': u'G',
#   u'revenue': 84460846,
#   u'score_imdb': 7.3,
#   u'score_rtcritics': 74,
#   u'title': u'The Land Before Time'},
#  {u'_id': u'ymAnL4Nc3W2kNYZta',
#   u'actors': u'Charlie Sheen, Willem Dafoe, Tom Berenger, Forest Whitaker, Francesco Quinn',
#   u'directors': u'Oliver Stone',
#   u'genre': u'Drama, Action, War, Adventure',
#   u'genres': [u'Drama', u'Action', u'War', u'Adventure'],
#   u'plot': u'Chris Taylor, a young, naive recruit in Vietnam, faces a moral crisis when confronted with the horrors of war and the duality of man.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNTU3NzY4ODY5MF5BMl5BanBnXkFtZTcwOTkzNzE1NA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/sYPOQI57JVNmjiLI3KeZ5KA8O9i.jpg',
#   u'rating': u'R',
#   u'revenue': 138530565,
#   u'score_imdb': 8.2,
#   u'score_rtcritics': 88,
#   u'title': u'Platoon'},
#  {u'_id': u'QKWZiazxggv2Y6DHL',
#   u'actors': u'Robert Gunton, Tim Robbins, Morgan Freeman, Bob Gunton, William Sadler',
#   u'directors': u'Frank Darabont',
#   u'genre': u'Drama, Crime',
#   u'genres': [u'Drama', u'Crime'],
#   u'plot': u'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BODU4MjU4NjIwNl5BMl5BanBnXkFtZTgwMDU2MjEyMDE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/9O7gLzmreU0nGkIB6K3BsJbzvNv.jpg',
#   u'rating': u'R',
#   u'revenue': 28341469,
#   u'score_imdb': 9.3,
#   u'score_metascore': 80,
#   u'score_rtcritics': 91,
#   u'title': u'The Shawshank Redemption'},
#  {u'_id': u'oFTC8Z9o2JBvHq73y',
#   u'actors': u'Walter Pidgeon, Anne Francis, Leslie Nielsen, Warren Stevens, Jack Kelly',
#   u'directors': u'Fred McLeod Wilcox, Fred M. Wilcox',
#   u'genre': u'Mystery, Family, Fantasy, Drama, Science Fiction, Suspense, Adventure, Action, Classics',
#   u'genres': [u'Mystery',
#    u'Family',
#    u'Fantasy',
#    u'Drama',
#    u'Science Fiction',
#    u'Suspense',
#    u'Adventure',
#    u'Action',
#    u'Classics'],
#   u'plot': u'Captain Adams and the crew of the Starship C57D fly towards planet Altair 4 in search for the Bellerphon spaceship that has been missing for twenty years. To their surprise they are already being expected. A classic science fiction film from 1957 starring Leslie Nielsen.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTMxOTc2NzgxMF5BMl5BanBnXkFtZTcwNzYxNDcyMg@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/qdH1Fm5vl1DAjXNHPmRZ4yEiUgM.jpg',
#   u'rating': u'G',
#   u'revenue': 23500000,
#   u'score_imdb': 7.7,
#   u'score_rtcritics': 98,
#   u'title': u'Forbidden Planet'},
#  {u'_id': u'wyvmK8RoKdMwzXRHW',
#   u'actors': u'Paul Shenar, Jodi Hicks, Ian Fried, Tom Hatten, Lucille Bliss',
#   u'directors': u'Don Bluth',
#   u'genre': u'Kids, Family, Fantasy, Drama, Science Fiction, Animation',
#   u'genres': [u'Kids',
#    u'Family',
#    u'Fantasy',
#    u'Drama',
#    u'Science Fiction',
#    u'Animation'],
#   u'plot': u"A widowed field mouse must move her family -- including an ailing son -- to escape a farmer's plow. Aided by a crow and a pack of superintelligent, escaped lab rats, the brave mother struggles to transplant her home to firmer ground.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNTEwMDEyNzI2OV5BMl5BanBnXkFtZTcwNTAxMDc2NA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/qXvgbM2cIjkoOPgzxn0hwiSUqk6.jpg',
#   u'rating': u'G',
#   u'revenue': 14665733,
#   u'score_imdb': 7.6,
#   u'score_rtcritics': 96,
#   u'title': u'The Secret of NIMH'},
#  {u'_id': u'Kt5orKF4Q5u5is9hz',
#   u'actors': u"Wil Wheaton, River Phoenix, Corey Feldman, Jerry O'Connell, Kiefer Sutherland",
#   u'directors': u'Rob Reiner',
#   u'genre': u'Drama, Action, Adventure, Crime',
#   u'genres': [u'Drama', u'Action', u'Adventure', u'Crime'],
#   u'plot': u'The film\'s name comes from the song "Stand By Me" by Ben E. King from 1961. The song was also the theme song. This film was modeled from a novella by Stephen King called "The Body" and was the ninth filmed story from the author. The film tells the story of a group of 10-year-old friends out on their own and the trials and tribulation they are confronted with along the journey.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNDk2MTkyMTA1OF5BMl5BanBnXkFtZTcwOTc2Njk3OA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/98qQLkTKEdWo3UVBzzeaetwNeQD.jpg',
#   u'rating': u'R',
#   u'revenue': 52287000,
#   u'score_imdb': 8.1,
#   u'score_rtcritics': 91,
#   u'title': u'Stand by Me'},
#  {u'_id': u'xcrtWCCYHJRgrhLqN',
#   u'actors': u'Jurgen Prochnow, Herbert Gronemeyer, Klaus Wennemann, Hubertus Bengsch, Martin Semmelrogge',
#   u'directors': u'Wolfgang Peterses, Wolfgang Petersen',
#   u'genre': u'Drama, Action, History, Adventure, War',
#   u'genres': [u'Drama', u'Action', u'History', u'Adventure', u'War'],
#   u'plot': u'A German submarine hunts allied ships during the Second World War. Soon it becomes hunted itself. The crew tries to survive below the surface, while stretching both the boat and themselves to their limits...',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjE5Mzk5OTQ0Nl5BMl5BanBnXkFtZTYwNzUwMTQ5._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/twFxsOqOeQm7aAk62ZAmwYkV492.jpg',
#   u'rating': u'R',
#   u'revenue': 85000000,
#   u'score_imdb': 8.5,
#   u'score_metascore': 86,
#   u'score_rtcritics': 98,
#   u'title': u'The Boat'},
#  {u'_id': u'MQPoqfGTqoiK6pDGr',
#   u'actors': u'Ellar Coltrane, Patricia Arquette, Ethan Hawke, Lorelei Linklater, Elijah Smith',
#   u'directors': u'Richard Linklater',
#   u'genre': u'Drama',
#   u'genres': [u'Drama'],
#   u'plot': u'The film tells a story of a divorced couple trying to raise their young son. The story follows the boy for twelve years, from first grade at age 6 through 12th grade at age 17-18, and examines his relationship with his parents as he grows.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTYzNDc2MDc0N15BMl5BanBnXkFtZTgwOTcwMDQ5MTE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/eKi4e5zXhQKs0De4xu5AAMvu376.jpg',
#   u'rating': u'R',
#   u'revenue': 43000000,
#   u'score_imdb': 8.5,
#   u'score_metascore': 100,
#   u'score_rtcritics': 99,
#   u'title': u'Boyhood'},
#  {u'_id': u'3Tp279MKvJYzcYdYn',
#   u'actors': u'Basil The Great Mouse Detective, Susanne Pollatschek, Alan Young, Val Bettin, Melissa Manchester',
#   u'directors': u'Burny Mattinson, Ron Clements',
#   u'genre': u'Action, Kids, Animation, Adventure, Family',
#   u'genres': [u'Action', u'Kids', u'Animation', u'Adventure', u'Family'],
#   u'plot': u"In Victorian London, England, a little mouse girl's toymaker father is abducted by a peg-legged bat. She enlists the aid of Basil of Baker Street, the rodent world's answer to Sherlock Holmes. The case expands as Basil uncovers the crime's link to a plot against the Crown itself.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTUxNjY5MjU1MV5BMl5BanBnXkFtZTYwNjg2MzI5._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/7p2ekrptHyB2qPLwVkq7vvZL7mz.jpg',
#   u'rating': u'G',
#   u'revenue': 82424789,
#   u'score_imdb': 7.2,
#   u'score_rtcritics': 81,
#   u'title': u'The Great Mouse Detective'},
#  {u'_id': u'33p3jzpXNu4jSkvKg',
#   u'actors': u'Peter Gallagher, Alison Janney, Sam Roberts, Kevin Spacey, Annette Bening',
#   u'directors': u'Sam Mendes',
#   u'genre': u'Drama, Comedy',
#   u'genres': [u'Drama', u'Comedy'],
#   u'plot': u"Lester Burnham, a depressed suburban father in a mid-life crisis, decides to turn his hectic life around after developing an infatuation with his daughter's attractive friend.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjM4NTI5NzYyNV5BMl5BanBnXkFtZTgwNTkxNTYxMTE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/3UBQGKS8c1dxRnDiu5kUK6ej3pP.jpg',
#   u'rating': u'R',
#   u'revenue': 356296601,
#   u'score_imdb': 8.5,
#   u'score_metascore': 86,
#   u'score_rtcritics': 88,
#   u'title': u'American Beauty'},
#  {u'_id': u'6N8k8ph44KDPhtHez',
#   u'actors': u'James Mason, Kirk Douglas, Paul Lukas, Peter Lorre, Robert J. Wilke',
#   u'directors': u'Richard Fleischer',
#   u'genre': u'Kids, Family, Drama, Science Fiction, Adventure, Action',
#   u'genres': [u'Kids',
#    u'Family',
#    u'Drama',
#    u'Science Fiction',
#    u'Adventure',
#    u'Action'],
#   u'plot': u'A ship sent to investigate a wave of mysterious sinkings encounters the advanced submarine, the Nautilus, commanded by Captain Nemo.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BOTY4NTc1MTk3NV5BMl5BanBnXkFtZTgwMDI1NjE0MDE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/poYgoz8ARxYuB2Ej2uhAuamAufu.jpg',
#   u'rating': u'G',
#   u'revenue': 28200000,
#   u'score_imdb': 7.2,
#   u'score_rtcritics': 89,
#   u'title': u'20,000 Leagues Under the Sea'},
#  {u'_id': u'9dDENakd3Zrs37MXe',
#   u'actors': u'Greg Kinnear, Toni Collette, Steve Carell, Paul Dano, Abigail Breslin',
#   u'directors': u'Jonathan Dayton, Valerie Faris',
#   u'genre': u'Drama, Comedy, Adventure',
#   u'genres': [u'Drama', u'Comedy', u'Adventure'],
#   u'plot': u'Little Miss Sunshine is a comedy about a family of six who are all having a mental breakdown at the same time. To ease their mental lows they decide to take a cross country road trip to a \u201cLittle Miss Sunshine\u201d contest that their daughter has qualified for. An Academy Award winning comedy with memorable performances from its all actors.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTgzNTgzODU0NV5BMl5BanBnXkFtZTcwMjEyMjMzMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/j8iu2kdD0KWMcA3IMzCAhO8ULO.jpg',
#   u'rating': u'R',
#   u'revenue': 100320452,
#   u'score_imdb': 7.9,
#   u'score_metascore': 80,
#   u'score_rtcritics': 91,
#   u'title': u'Little Miss Sunshine'},
#  {u'_id': u'q3WtgA235w4RK26EA',
#   u'actors': u'Marlon Brando, Al Pacino, James Caan, Richard S. Castellano, Robert Duvall',
#   u'directors': u'Francis Ford Coppola',
#   u'genre': u'Drama, Crime',
#   u'genres': [u'Drama', u'Crime'],
#   u'plot': u'The story spans the years from 1945 to 1955 and chronicles the fictional Italian-American Corleone crime family. When organized crime family patriarch Vito Corleone barely survives an attempt on his life, his youngest son, Michael, steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjEyMjcyNDI4MF5BMl5BanBnXkFtZTcwMDA5Mzg3OA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/d4KNaTrltq6bpkFS01pYtyXa09m.jpg',
#   u'rating': u'R',
#   u'revenue': 245066411,
#   u'score_imdb': 9.2,
#   u'score_metascore': 100,
#   u'score_rtcritics': 100,
#   u'title': u'The Godfather'},
#  {u'_id': u'wHcwfRQzabBvkydtC',
#   u'actors': u'Bridgit Mendler, Amy Poehler, Will Arnett, Carol Burnett, David Henrie',
#   u'directors': u'Hiromasa Yonebayashi, Atsushi Okui',
#   u'genre': u'Family, Fantasy, Science Fiction, Animation, Adventure, International, Art House',
#   u'genres': [u'Family',
#    u'Fantasy',
#    u'Science Fiction',
#    u'Animation',
#    u'Adventure',
#    u'International',
#    u'Art House'],
#   u'plot': u'14-year-old Arrietty and the rest of the Clock family live in peaceful anonymity as they make their own home from items "borrowed" from the house\'s human inhabitants. However, life changes for the Clocks when a human boy discovers Arrietty.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTAxNjk3OTYyODReQTJeQWpwZ15BbWU3MDgyODY2OTY@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/A4w9oSNQUwtkaucy3K7LbSngKrk.jpg',
#   u'rating': u'G',
#   u'revenue': 148202743,
#   u'score_imdb': 7.7,
#   u'score_metascore': 80,
#   u'score_rtcritics': 95,
#   u'title': u'The Secret World of Arrietty'},
#  {u'_id': u'SpsWJiQee9pj3qtnt',
#   u'actors': u'Barbara Luddy, Larry Roberts, Bill Thompson, Stan Freberg, Verna Felton',
#   u'directors': u'Barbara Luddy, Bill Baucom',
#   u'genre': u'Kids, Family, Drama, Animation, Adventure, Comedy',
#   u'genres': [u'Kids',
#    u'Family',
#    u'Drama',
#    u'Animation',
#    u'Adventure',
#    u'Comedy'],
#   u'plot': u"Lady, a golden cocker spaniel, meets up with a mongrel dog who calls himself the Tramp. He is obviously from the wrong side of town, but happenings at Lady's home make her decide to travel with him for a while.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjAwNzA3NTk0NV5BMl5BanBnXkFtZTcwMzkyNDEzMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/kpfbF0C0lSvvKE3JQVuAGufA6UT.jpg',
#   u'rating': u'G',
#   u'revenue': 93600000,
#   u'score_imdb': 7.4,
#   u'score_rtcritics': 89,
#   u'title': u'Lady and the Tramp'},
#  {u'_id': u'Ljoquhydk4YDYFcYb',
#   u'actors': u'Matheus Nachtergaele, Alexandre Rodrigues, Leandro Firmino da Hora, Phellipe Haagensen, Phelipe Haagensen',
#   u'directors': u'Katia Lund, Fernando Meirelles',
#   u'genre': u'Crime, Drama, Adventure, Action, International, Art House',
#   u'genres': [u'Crime',
#    u'Drama',
#    u'Adventure',
#    u'Action',
#    u'International',
#    u'Art House'],
#   u'plot': u'City of God depicts the raw violence in the ghettos of Rio de Janeiro. In the 1970\u2019s that kids are carrying guns and joining gangs when they should be playing hide-and-seek.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjA4ODQ3ODkzNV5BMl5BanBnXkFtZTYwOTc4NDI3._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/gCqnQaq8T4CfioP9uETLx9iMJF4.jpg',
#   u'rating': u'R',
#   u'revenue': 27387381,
#   u'score_imdb': 8.7,
#   u'score_metascore': 79,
#   u'score_rtcritics': 90,
#   u'title': u'City of God'},
#  {u'_id': u'RG6qc96yYyRC8YJQv',
#   u'actors': u'David Emge, Ken Foree, Scott Reiniger, Gaylen Ross, David Crawford',
#   u'directors': u'George A. Romero',
#   u'genre': u'Action, Science Fiction, Horror, Adventure, Fantasy',
#   u'genres': [u'Action',
#    u'Science Fiction',
#    u'Horror',
#    u'Adventure',
#    u'Fantasy'],
#   u'plot': u'During an ever-growing epidemic of zombies that have risen from the dead, two Philadelphia SWAT team members, a traffic reporter, and his television-executive girlfriend seek refuge in a secluded shopping mall.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjE1NzI5OTA1OF5BMl5BanBnXkFtZTcwMjg1MDUyMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/8D6WEfNZr6JadQrqJr5OOq1QlV0.jpg',
#   u'rating': u'R',
#   u'revenue': 55000000,
#   u'score_imdb': 8,
#   u'score_rtcritics': 95,
#   u'title': u'Dawn of the Dead'},
#  {u'_id': u'kBBXKdHRiG4uo5hkS',
#   u'actors': u"Paige O'Hara, Robby Benson, Richard White, Jerry Orbach, David Ogden Stiers",
#   u'directors': u'Gary Trousdale, Bill Condon',
#   u'genre': u'Drama, Performing Arts, Kids, Family, Science Fiction, Romance, Fantasy, Animation, Music, Musical',
#   u'genres': [u'Drama',
#    u'Performing Arts',
#    u'Kids',
#    u'Family',
#    u'Science Fiction',
#    u'Romance',
#    u'Fantasy',
#    u'Animation',
#    u'Music',
#    u'Musical'],
#   u'plot': u"Follow the adventures of Belle, a bright young woman who finds herself in the castle of a prince who's been turned into a mysterious beast. With the help of the castle's enchanted staff, Belle soon learns the most important lesson of all -- that true beauty comes from within.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTkyMDgwODY0OV5BMl5BanBnXkFtZTgwODI5NTQ5MTE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/b9QJr2oblOu1grgOMUZF1xkUJdh.jpg',
#   u'rating': u'G',
# ...
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/zSgL998DXaljsCmwQuwDM8Ak4rV.jpg',
#   u'rating': u'R',
#   u'revenue': 240031094,
#   u'score_imdb': 7.1,
#   u'score_metascore': 67,
#   u'score_rtcritics': 66,
#   u'title': u'Die Hard 2'},
#  {u'_id': u'46k3mtitmi9aq2gfb',
#   u'actors': u'Marlon Brando, Christopher Reeve, Gene Hackman, Margot Kidder, Ned Beatty',
#   u'directors': u'Jonathan Barry, David Tomblin',
#   u'genre': u'Sci-Fi, Family, Science Fiction, Romance, Fantasy, Adventure, Action, Comedy',
#   u'genres': [u'Sci-Fi',
#    u'Family',
#    u'Science Fiction',
#    u'Romance',
#    u'Fantasy',
#    u'Adventure',
#    u'Action',
#    u'Comedy'],
#   u'plot': u"Mild-mannered Clark Kent works as a reporter at the Daily Planet alongside his crush, Lois Lane \u2212 who's in love with Superman. Clark must summon his superhero alter ego when the nefarious Lex Luthor launches a plan to take over the world.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTI1MjA5MzM0OF5BMl5BanBnXkFtZTYwNTc0MTQ5._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/rLTdj7oB9oxsYwuweeglWRzRng7.jpg',
#   u'rating': u'PG',
#   u'revenue': 300218018,
#   u'score_imdb': 7.4,
#   u'score_metascore': 86,
#   u'score_rtcritics': 93,
#   u'title': u'Superman'},
#  {u'_id': u'Lq76gEj5fsBRbRYhr',
#   u'actors': u'Emilio Echevarria, Emilio Echeverria, Gael Garcia Bernal, Goya Toledo, Alvaro Guerrero',
#   u'directors': u'Alejandro Gonzalez Inarritu',
#   u'genre': u'Drama, International, Art House, Thriller',
#   u'genres': [u'Drama', u'International', u'Art House', u'Thriller'],
#   u'plot': u'Three interconnected stories about the different strata of life in Mexico City all resolve with a fatal car accident. Octavio is trying to raise enough money to run away with his sister-in-law, and decides to enter his dog Cofi into the world of dogfighting. After a dogfight goes bad, Octavio flees in his car, running a red light and causing the accident. Daniel and Valeria\'s new-found bliss is prematurely ended when she loses her leg in the accident. El Chivo is a homeless man who cares for stray dogs and is there to witness the collision. Amores Perros is the first film in I\xf1\xe1rritu\'s "Death Trilogy".',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjIyNTA5MzQ5N15BMl5BanBnXkFtZTcwNjIyNTgxMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/8gEXmIzw1tDnBfOaCFPimkNIkmm.jpg',
#   u'rating': u'R',
#   u'revenue': 21000000,
#   u'score_imdb': 8.1,
#   u'score_metascore': 83,
#   u'score_rtcritics': 92,
#   u'title': u'Amores Perros'},
#  {u'_id': u'DpPdRD7B8SafJWdMg',
#   u'actors': u'Al Pacino, Jack Lemmon, Alec Baldwin, Ed Harris, Alan Arkin',
#   u'directors': u'James Foley',
#   u'genre': u'Drama, Mystery, Thriller, Crime',
#   u'genres': [u'Drama', u'Mystery', u'Thriller', u'Crime'],
#   u'plot': u'Glengarry Glen Ross, follows the lives of four unethical Chicago real estate agents who are prepared to go to any lengths (legal or illegal) to unload undesirable real estate on unwilling prospective buyers.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTM5MjYyNTQ5MF5BMl5BanBnXkFtZTgwMDM1MzcxMTE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/4YgCTLcHEIeGyzrKpwz93rORb8l.jpg',
#   u'rating': u'R',
#   u'revenue': 10725228,
#   u'score_imdb': 7.9,
#   u'score_metascore': 80,
#   u'score_rtcritics': 94,
#   u'title': u'Glengarry Glen Ross'},
#  {u'_id': u'ovCndnuRf6byPT4Qc',
#   u'actors': u'Ben Foster, Noomi Rapace, Michael Fassbender, Charlize Theron, Idris Elba',
#   u'directors': u'Ridley Scott',
#   u'genre': u'Mystery, Sci-Fi, Fantasy, Horror, Drama, Science Fiction, Adventure, Action',
#   u'genres': [u'Mystery',
#    u'Sci-Fi',
#    u'Fantasy',
#    u'Horror',
#    u'Drama',
#    u'Science Fiction',
#    u'Adventure',
#    u'Action'],
#   u'plot': u'A team of explorers discover a clue to the origins of mankind on Earth, leading them on a journey to the darkest corners of the universe. There, they must fight a terrifying battle to save the future of the human race.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTY3NzIyNTA2NV5BMl5BanBnXkFtZTcwNzE2NjI4Nw@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/idXq7NctkwoH59DRAIQlHEPtn95.jpg',
#   u'rating': u'R',
#   u'revenue': 403170142,
#   u'score_imdb': 7,
#   u'score_metascore': 65,
#   u'score_rtcritics': 73,
#   u'title': u'Prometheus'},
#  {u'_id': u'DBM3eNu38X4Msr23o',
#   u'actors': u'Mark De Carlo, Megan Cavanagh, Debi Derryberry, Jeff Garcia, Bob Goen',
#   u'directors': u'John Davis, John A. Davis',
#   u'genre': u'Kids, Family, Fantasy, Science Fiction, Animation, Adventure, Action, Comedy',
#   u'genres': [u'Kids',
#    u'Family',
#    u'Fantasy',
#    u'Science Fiction',
#    u'Animation',
#    u'Adventure',
#    u'Action',
#    u'Comedy'],
#   u'plot': u"Jimmy Neutron is a boy genius and way ahead of his friends, but when it comes to being cool, he's a little behind. All until one day when his parents, and parents all over Earth are kidnapped by aliens, it's up to him to lead all the children of the world to rescue their parents.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTk5MTQ0NTM1Nl5BMl5BanBnXkFtZTcwNDkyNjIyMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/l8p1fcUaqGJJMvPFtnXC2Uz079f.jpg',
#   u'rating': u'G',
#   u'revenue': 80936232,
#   u'score_imdb': 6,
#   u'score_metascore': 65,
#   u'score_rtcritics': 75,
#   u'title': u'Jimmy Neutron: Boy Genius'},
#  {u'_id': u'29qZy2g3y7BteebXB',
#   u'actors': u'Gene Wilder, Peter Boyle, Marty Feldman, Madeline Kahn, Cloris Leachman',
#   u'directors': u'Mel Brooks',
#   u'genre': u'Classics, Horror, Comedy, Fantasy, Science Fiction',
#   u'genres': [u'Classics',
#    u'Horror',
#    u'Comedy',
#    u'Fantasy',
#    u'Science Fiction'],
#   u'plot': u'A young neurosurgeon (Gene Wilder) inherits the castle of his grandfather, the famous Dr. Victor von Frankenstein. In the castle he finds a funny hunchback called Igor, a pretty lab assistant named Inga and the old housekeeper, Frau Blucher. Young Frankenstein believes that the work of his grandfather was delusional, but when he discovers the book where the mad doctor described his reanimation experiment, he suddenly changes his mind...',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTEwNjg2MjM2ODFeQTJeQWpwZ15BbWU4MDQ1MDU5OTEx._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/a3Bj2ht6liBFafNM46hqk9WEhcY.jpg',
#   u'rating': u'PG',
#   u'revenue': 86273333,
#   u'score_imdb': 8.1,
#   u'score_rtcritics': 94,
#   u'title': u'Young Frankenstein'},
#  {u'_id': u'r2uEvXCoAYS8P7RFv',
#   u'actors': u'Tom Hanks, Paul Newman, Jennifer Jason Leigh, Jude Law, Stanley Tucci',
#   u'directors': u'Sam Mendes',
#   u'genre': u'Drama, Thriller, Crime',
#   u'genres': [u'Drama', u'Thriller', u'Crime'],
#   u'plot': u'Mike Sullivan works as a hit man for crime boss John Rooney. Sullivan views Rooney as a father figure, however after his son is witness to a killing, Mike Sullivan finds himself on the run in attempt to save the life of his son and at the same time looking for revenge on those who wronged him.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjA0MDM4ODM0Ml5BMl5BanBnXkFtZTYwNDE3MjU3._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/jn0GH8klINSQtRNifY8W2Kv4ajl.jpg',
#   u'rating': u'R',
#   u'revenue': 181001478,
#   u'score_imdb': 7.8,
#   u'score_metascore': 72,
#   u'score_rtcritics': 81,
#   u'title': u'Road to Perdition'},
#  {u'_id': u'8heK2nJ8fEw6jYBTD',
#   u'actors': u'Jamie Lee Curtis, Kevin Kline, Michael Palin, Maria Aitken, Tom Georgeson',
#   u'directors': u'John Cleese, Charles Crichton',
#   u'genre': u'Comedy, Crime',
#   u'genres': [u'Comedy', u'Crime'],
#   u'plot': u'A diamond advocate is attempting to steal a collection of diamonds, yet troubles arise when he realizes that he is not the only one after the diamonds.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjE5OTIzODI4Nl5BMl5BanBnXkFtZTcwNDg3NzYzNA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/9gZZyQ8XStpUJBFU1ceU4xx1crv.jpg',
#   u'rating': u'R',
#   u'revenue': 62493712,
#   u'score_imdb': 7.6,
#   u'score_metascore': 80,
#   u'score_rtcritics': 93,
#   u'title': u'A Fish Called Wanda'},
#  {u'_id': u'nrTjHKXRAQeu3CiEC',
#   u'actors': u'Johnny Depp, Christian Bale, Marion Cotillard, Billy Crudup, Channing Tatum',
#   u'directors': u'Michael Mann',
#   u'genre': u'Biography, Crime, Drama, Adventure, Action, Thriller',
#   u'genres': [u'Biography',
#    u'Crime',
#    u'Drama',
#    u'Adventure',
#    u'Action',
#    u'Thriller'],
#   u'plot': u'In the shadow of the Great Depression, criminal minds are thriving -- notorious men such as John Dillinger, "Baby Face" Nelson and "Pretty Boy" Floyd -- and it\'s up to J. Edgar Hoover and the FBI to bring them down in this gritty crime drama.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjA3NDI0NzM2MV5BMl5BanBnXkFtZTcwODk5MTk2Mg@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/zcHgW9WvtM6s7VxDXAZAoNJYlz6.jpg',
#   u'rating': u'R',
#   u'revenue': 214104620,
#   u'score_imdb': 7,
#   u'score_metascore': 70,
#   u'score_rtcritics': 68,
#   u'title': u'Public Enemies'},
#  {u'_id': u'mkQBj4RjA6bLQMzHa',
#   u'actors': u'Joaquin Phoenix, Mark Wahlberg, Eva Mendes, Robert Duvall, Antoni Corone',
#   u'directors': u'James Gray',
#   u'genre': u'Drama, Action, Adventure, Thriller, Crime',
#   u'genres': [u'Drama', u'Action', u'Adventure', u'Thriller', u'Crime'],
#   u'plot': u'A New York nightclub manager tries to save his brother and father from Russian mafia hit men.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTY0MTQ5OTcyNF5BMl5BanBnXkFtZTcwMDE0NzUzMw@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/lTaU9Qqjew0qFWcEIdMpeV4VbuF.jpg',
#   u'rating': u'R',
#   u'revenue': 54591330,
#   u'score_imdb': 6.9,
#   u'score_metascore': 59,
#   u'score_rtcritics': 57,
#   u'title': u'We Own the Night'},
#  {u'_id': u'8rR4ahpPhjoKWxfZ3',
#   u'actors': u'Naseeruddin Shah, Lillete Dubey, Shefali Shetty, Vijay Raaz, Tilotama Shome',
#   u'directors': u'Mira Nair',
#   u'genre': u'Drama, Romance, Comedy',
#   u'genres': [u'Drama', u'Romance', u'Comedy'],
#   u'plot': u'From an exciting Indian wedding comes a relationship from two different times not only showing the modern but also the traditional. Different characters and stories interact with each other in director Mira Nair film where he used an Indian-American production to illustrate these themes modern day Indians are very familiar with.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTU5NTA5MjUyMl5BMl5BanBnXkFtZTcwOTQ3NDc3Mg@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/aRWp1b8IhmAr12dbermVaqoV2bl.jpg',
#   u'rating': u'R',
#   u'revenue': 30787356,
#   u'score_imdb': 7.4,
#   u'score_metascore': 77,
#   u'score_rtcritics': 95,
#   u'title': u'Monsoon Wedding'},
#  {u'_id': u'n6wCxayAwsiaCgtE7',
#   u'actors': u'Carmen Lee, Ben Affleck, Joey Lauren Adams, Jason Lee, Dwight Ewell',
#   u'directors': u'Kevin Smith',
#   u'genre': u'Drama, Romance, Comedy',
#   u'genres': [u'Drama', u'Romance', u'Comedy'],
#   u'plot': u"Holden and Banky are comic book artists. Everything is going good for them until they meet Alyssa, also a comic book artist. Holden falls for her, but his hopes are crushed when he finds out she's a lesbian.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTY5ODMyMDY4NF5BMl5BanBnXkFtZTcwNDgwMDEyMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/4vFJileWrCGaBeobCmF0tXpQCUb.jpg',
#   u'rating': u'R',
#   u'revenue': 12021272,
#   u'score_imdb': 7.4,
#   u'score_metascore': 71,
#   u'score_rtcritics': 88,
#   u'title': u'Chasing Amy'},
#  {u'_id': u'KcvpeXioN7qfzPiTw',
#   u'actors': u'Frank Lovell, Bill Paxton, Tom Hanks, Kevin Bacon, Gary Sinise',
#   u'directors': u'Ron Howard',
#   u'genre': u'Drama, Action, Documentary, Adventure, History',
#   u'genres': [u'Drama', u'Action', u'Documentary', u'Adventure', u'History'],
#   u'plot': u"Technical troubles scuttle the Apollo 13 lunar mission in 1971, risking the lives of astronaut Jim Lovell and his crew in director Ron Howard's chronicle of this true-life story, which turns a failed journey into a thrilling saga of heroism. Drifting more than 200,000 miles from Earth, the astronauts work furiously with the ground crew to avert tragedy.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTM2Njg2NjU5NF5BMl5BanBnXkFtZTYwODI5MDc4._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/6JQ9z3V9x4vlU2GSZx2yNO0PvuX.jpg',
#   u'rating': u'PG',
#   u'revenue': 355237933,
#   u'score_imdb': 7.6,
#   u'score_metascore': 77,
#   u'score_rtcritics': 95,
#   u'title': u'Apollo 13'},
#  {u'_id': u'mi3JCF3pxxtFG9Hna',
#   u'actors': u'James McAvoy, Keira Knightley, Saoirse Ronan, Brenda Blethyn, Romola Garai',
#   u'directors': u'Joe Wright',
#   u'genre': u'Drama, Mystery, Romance',
#   u'genres': [u'Drama', u'Mystery', u'Romance'],
#   u'plot': u"Fledgling writer Briony Tallis, as a 13-year-old, irrevocably changes the course of several lives when she accuses her older sister's lover of a crime he did not commit. Based on the British romance novel by Ian McEwan.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTM0ODc2Mzg1Nl5BMl5BanBnXkFtZTcwMTg4MDU1MQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/quaWuwYZd8IbZMCOhW3CZEvyCWJ.jpg',
#   u'rating': u'R',
#   u'revenue': 129266061,
#   u'score_imdb': 7.8,
#   u'score_metascore': 85,
#   u'score_rtcritics': 83,
#   u'title': u'Atonement'},
#  {u'_id': u'8nNfyvBHuEncEvusP',
#   u'actors': u'Tadanobu Asano, Honglei Sun, Khulan Chuluun, Aliya, Amarbold Yuvinbayar',
#   u'directors': u'Sergei Bodrov, Sergey Bodrov',
#   u'genre': u'Drama, Classics, Adventure, Biography, History',
#   u'genres': [u'Drama', u'Classics', u'Adventure', u'Biography', u'History'],
#   u'plot': u'The story recounts the early life of Genghis Khan, a slave who went on to conquer half the world in the 11th century.  Released in the US and the UK as "Mongol: The Rise to Power of Genghis Khan"',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTQ0NTgzMzA2N15BMl5BanBnXkFtZTcwNTI1NjQ2MQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/joGzMb7ipGrHuE7PDd4iK4q5uy3.jpg',
#   u'rating': u'R',
#   u'revenue': 26527510,
#   u'score_imdb': 7.3,
#   u'score_metascore': 74,
#   u'score_rtcritics': 86,
#   u'title': u'Mongol'},
#  {u'_id': u'u2kGnR3DMay7qnjHb',
#   u'actors': u'Francis Healy, Geraldine McEwan, Anne-Marie Duff, Nora-Jane Noone, Dorothy Duffy',
#   u'directors': u'Peter Mullan',
#   u'genre': u'Drama, Foreign',
#   u'genres': [u'Drama', u'Foreign'],
#   u'plot': u'Four women are given into the custody of the Magdalene sisterhood asylum to correct their sinful behavior: Crispina and Rose have given birth to a premarital child, Margaret got raped by her cousin and the orphan Bernadette had been repeatedly caught flirting with the boys. All have to work in a laundry under the strict supervision of the nuns, who break their wills through sadistic punishment.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTI2NzU1NTc1NF5BMl5BanBnXkFtZTcwOTQ1MjAwMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/gKUvSlDfg9em00y3Yxofh6s5jvv.jpg',
#   u'rating': u'R',
#   u'revenue': 20957001,
#   u'score_imdb': 7.8,
#   u'score_metascore': 83,
#   u'score_rtcritics': 90,
#   u'title': u'The Magdalene Sisters'},
#  {u'_id': u'oHCLnCc3Yg4uiFYZq',
#   u'actors': u'Orlando Bloom, Liam Neeson, Eva Green, David Thewlis, Jeremy Irons',
#   u'directors': u'Ridley Scott',
#   u'genre': u'Drama, Adventure, Action, Classics, War, History',
#   u'genres': [u'Drama',
#    u'Adventure',
#    u'Action',
#    u'Classics',
#    u'War',
#    u'History'],
#   u'plot': u'After his wife dies, a blacksmith named Balian is thrust into royalty, political intrigue and bloody holy wars during the Crusades.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjE2MTIwNjg0MV5BMl5BanBnXkFtZTcwNjAxODIzMw@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/d9GYuT9aMoDi4MPTKYe4M2PwUm4.jpg',
#   u'rating': u'R',
#   u'revenue': 211643158,
#   u'score_imdb': 7.2,
#   u'score_metascore': 63,
#   u'score_rtcritics': 39,
#   u'title': u'Kingdom of Heaven'}]

# %%
job
