# %%
import sklearn
from pymongo import MongoClient
import sys
sys.path.insert(0, '/Users/tdelteil/Projects/Filmgrid/pythonApp/vendor/mongoqueue')
from mongoqueue import MongoQueue
import time
import string
from random import randint
from __future__ import division

# %%
uri = 'mongodb://localhost/appdb'
client = MongoClient(uri)

# %%
queue = MongoQueue(
client.appdb.jobqueue,
consumer_id="consumer-1",
timeout=300,
max_attempts=3)

# %%
movieCache = dict();
allMovies = 0;

# %%
def getMovie(movieId):
    if movieId in movieCache:
        return movieCache[movieId]
    else:
        m = client.appdb.movies.find_one({"_id":movieId})
        if (m) :
            movieCache[movieId] = m
        else :
            raise Exception("You are a terrible coder")
        return m

# %%
def updateMovies(userId, newMovies, myMovies):
    newSet = dict()
    for m in myMovies.values():
        if (m['statusType'] != 'suggested'):
            newSet[m["id"]] = m
    missing = max(100,len(myMovies) - len(newSet));
    count = 0
    for m in newMovies:
        if (count >= missing):
            break
        if (m["_id"] not in newSet):
            m["statusType"] = 'suggested'
            m["statusScore"] = ''
            m["id"] = m["_id"]
            newSet[m["_id"]] = m
            count = count + 1
    
        
    
    client.appdb.users.update({"_id" : userId}, {"$set" : {'profile.new_movies':newSet}})

# %%
 allMovies = list(client.appdb.movies.find({},{'genres':1,'title':1,'rating':1,'directors':1,'score_metascore':1,
                                              'score_rtcritics':1, 'score_imdb':1,'revenue':1,'_id':1, 'poster':1,
                                              'poster_1':1,'plot':1,'directors':1,'actors':1,'genre':1,'runtime':1,
                                              'link_imdb':1,'link_rt':1,'changed':1,'year':1,'trailer_youtube':1}))

while(1):
    job = queue.next();
    while(job):
        t0 = time.time();
        userId = job.payload["userId"]
        myMovies = getMovies(userId)
        myMoviesValue = myMovies.values();
        myPreferences = computePreferences(myMoviesValue)
        myRecommendations = findRecommendations(myPreferences, allMovies)
        updateMovies(userId, myRecommendations, myMovies)
        job.complete();
        job = queue.next();
        print (time.time() -t0)
    time.sleep(1);
# Out:
# 0.187330007553
# 0.232439041138
# 0.264801025391
# 0.240156888962
# 0.221127986908
# 0.276765823364
# 0.18693614006
# 0.217039108276
# 0.189202070236
# 0.252304077148
# 0.222543001175
# 0.249862909317
# 0.315306186676
# 0.192981004715
# 0.198466062546
# 0.199744939804

# %%
def getMovies(userId):
    return client.appdb.users.find_one({"_id":userId},{"profile.movies" : 1})["profile"]["movies"];

allMovies = list(client.appdb.movies.find({},{'genres':1,'title':1,'rating':1,'directors':1,'score_metascore':1,
                                              'score_rtcritics':1, 'score_imdb':1,'revenue':1,'_id':1, 'poster':1,
                                              'poster_1':1,'plot':1,'directors':1,'actors':1,'genre':1}))

# %%
status = dict({
    'suggested': 0,
    'liked3': 3,
    'liked2': 2,
    'liked1': 0,
    'disliked': -2,
    'bookmarked': 1,
    'hidden': 0,
})

features = ["genre", "rating"]
featuresWeight = {'genre': 1, 'rating':1, 'directors':2}
featuresNorm = {"genre":dict(), "rating":dict(), "directors":dict()}

for feature in features:
    for m in allMovies:
        featureM = feature + 's' if feature+'s' in m else feature
        for item in m[featureM]:
            if(item not in featuresNorm[feature]):
                featuresNorm[feature][item]=0
            featuresNorm[feature][item] += 1
            

def computePreferences(userMovies):
    preferences = dict()
    for feature in features:
        preferences[feature] = dict()

    count = 0
    for movie in userMovies:
        weight = status[movie['statusType'] + str(movie['statusScore'])]
        if (weight != 0):
            count = count+1
            for feature in features:
                if (feature in movie and movie[feature]):
                    f = string.split(movie[feature],', ') #split the string to make it an array
                    if (len(f)):
                        norm = 1.0/len(f)

                        for item in f:
                            if (item not in preferences[feature]):
                                preferences[feature][item] = 0.0;
                            preferences[feature][item] += weight*norm

    for feature in preferences:
        for item in preferences[feature]:
            preferences[feature][item] /= count
    return preferences


def getMovieScore(userPreferences, movie):
    scores = dict()
    for feature in userPreferences:
        scores[feature] = 0.1
        features = movie[feature+'s'] if (feature+'s' in movie) else movie[feature] if feature in movie else []
        norm = len(features)
        for f in features:
            if (f in userPreferences[feature]):
                scores[feature] += userPreferences[feature][f]/norm
        
    
    revenue = min(10000000,max(movie['revenue'], 1000000))
    rating = 0.5
    if ('score_imdb' in movie):
        rating = movie['score_imdb'] / 10
    elif ('score_rtcritics' in movie):
        rating = movie['score_rtcritics'] / 100
    elif ('score_metascore' in movie):
        rating = movie['score_metascore'] / 100
        
    sumScore = 0
    for score in scores:
        sumScore += scores[score]*featuresWeight[score]
    
    return sumScore * revenue * rating


def findRecommendations(userGenres, allMovies):
    sort = sorted(allMovies, key=lambda s: -getMovieScore(userGenres, s) )[0:500]
    return sort[0:500]

# %%
myMovies = getMovies('4M4PbiRfrsmdDfQRM').values()

# %%
myPreferences = computePreferences(myMovies)

print myPreferences
# Out:
# {'genre': {}, 'rating': {u'PG-13': 1.6153846153846154, u'G': 0.23076923076923078, u'PG': 0.6923076923076923}}

# %%
findRecommendations(myPreferences, allMovies)
# Out:
# [{u'_id': u'Qfoq43xWGekWjKjsP',
#   u'actors': u'Jason Weaver, David McCharen, Cathy Cavadini, Judi M. Durand, Matthew Broderick',
#   u'directors': u'Roger Allers, Rob Minkoff',
#   u'genres': [u'Animation', u'Family'],
#   u'plot': u"A young lion cub named Simba can't wait to be king. But his uncle craves the title for himself and will stop at nothing to get it.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjEyMzgwNTUzMl5BMl5BanBnXkFtZTcwNTMxMzM3Ng@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/bKPtXn9n4M4s8vvZrbw40mYsefB.jpg',
#   u'rating': u'G',
#   u'revenue': 788241776,
#   u'score_imdb': 8.5,
#   u'score_metascore': 83,
#   u'score_rtcritics': 90,
#   u'title': u'The Lion King'},
#  {u'_id': u'fWb8foETB4qgouJM8',
#   u'actors': u'Macintalk, Ben Burtt, Elissa Knight, Jeff Garlin, Fred Willard',
#   u'directors': u'Andrew Stanton',
#   u'genres': [u'Animation', u'Family'],
#   u'plot': u"WALL-E is the last robot left on an Earth that has been overrun with garbage and all humans have fled to outer space. For 700 years he has continued to try and clean up the mess, but has developed some rather interesting human-like qualities. When a ship arrives with a sleek new type of robot, Wall-E thinks he's finally found a friend and stows away on the ship when it leaves.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTczOTA3MzY2N15BMl5BanBnXkFtZTcwOTYwNjE2MQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/4qOKgcDcB0SojUIg2syzor1FeL7.jpg',
#   u'rating': u'G',
#   u'revenue': 521311860,
#   u'score_imdb': 8.5,
#   u'score_metascore': 94,
#   u'score_rtcritics': 96,
#   u'title': u'WALL\xb7E'},
#  {u'_id': u'6tegyNDZLHyFqNFLx',
#   u'actors': u'Emily Hahn, Tom Hanks, Tim Allen, Joan Cusack, Ned Beatty',
#   u'directors': u'Lee Unkrich',
#   u'genres': [u'Comedy', u'Animation', u'Family'],
#   u'plot': u"Woody, Buzz, and the rest of Andy's toys haven't been played with in years. With Andy about to go to college, the gang find themselves accidentally left at a nefarious day care center. The toys must band together to escape and return home to Andy.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTgxOTY4Mjc0MF5BMl5BanBnXkFtZTcwNTA4MDQyMw@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/tOwAAVeL1p3ls9dhOBo45ElodU3.jpg',
#   u'rating': u'G',
#   u'revenue': 1063171911,
#   u'score_imdb': 8.4,
#   u'score_metascore': 92,
#   u'score_rtcritics': 99,
#   u'title': u'Toy Story 3'},
#  {u'_id': u'FjGS5kWuAgBYwDsow',
#   u'actors': u'Shahrukh Khan, Kajol, Anupam Kher, Farida Jalal, Amrish Puri',
#   u'directors': u'Aditya Chopra',
#   u'genres': [u'Drama', u'Romance', u'Comedy'],
#   u'plot': u'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fianc\xe9. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTk1MTg3MTA1OV5BMl5BanBnXkFtZTcwOTAxMzIyMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/q9z5xhtmq4tPtMqOiQk4BjbodbV.jpg',
#   u'rating': u'G',
#   u'revenue': 10320000,
#   u'score_imdb': 8.4,
#   u'title': u'Dilwale Dulhania Le Jayenge'},
#  {u'_id': u'z8C94GzZahxeMEcYo',
#   u'actors': u'Greg Berg, Kendall Cunningham, Sherry Lynn, Scott McAfee, Patrick Pinney',
#   u'directors': u'John Lasseter',
#   u'genres': [u'Comedy', u'Animation', u'Family'],
#   u'plot': u'Woody the cowboy is young Andy\u2019s favorite toy. Yet this changes when Andy get the new super toy Buzz Lightyear for his birthday. Now that Woody is no longer number one he plans his revenge on Buzz. Toy Story is a milestone in film history for being the first feature film to use entirely computer animation.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTgwMjI4MzU5N15BMl5BanBnXkFtZTcwMTMyNTk3OA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/agy8DheVu5zpQFbXfAdvYivF2FU.jpg',
#   u'rating': u'G',
#   u'revenue': 361958736,
#   u'score_imdb': 8.3,
#   u'score_metascore': 92,
#   u'score_rtcritics': 100,
#   u'title': u'Toy Story'},
#  {u'_id': u'JyYNxnqDF6dz2cG3P',
#   u'actors': u'Keir Dullea, Gary Lockwood, William Sylvester, Daniel Richter, Leonard Rossiter',
#   u'directors': u'Stanley Kubrick',
#   u'genres': [u'Mystery', u'Science Fiction', u'Adventure'],
#   u'plot': u'Humanity finds a mysterious, obviously artificial, object buried beneath the Lunar surface and, with the intelligent computer H.A.L. 9000, sets off on a quest.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNDYyMDgxNDQ5Nl5BMl5BanBnXkFtZTcwMjc1ODg3OA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/eDiexVN4nO3ZdDZCDMiJOX5fQ5r.jpg',
#   u'rating': u'G',
#   u'revenue': 56715371,
#   u'score_imdb': 8.3,
#   u'score_metascore': 86,
#   u'score_rtcritics': 96,
#   u'title': u'2001: A Space Odyssey'},
#  {u'_id': u'aEb7MXyZgvJQwcxvH',
#   u'actors': u'Alison Janney, Nicolas Bird, Albert Brooks, Ellen DeGeneres, Alexander Gould',
#   u'directors': u'Andrew Stanton, Lee Unkrich',
#   u'genres': [u'Comedy', u'Animation', u'Adventure', u'Family'],
#   u'plot': u"A tale which follows the comedic and eventful journeys of two fish, the fretful Marlin and his young son Nemo, who are separated from each other in the Great Barrier Reef when Nemo is unexpectedly taken from his home and thrust into a fish tank in a dentist's office overlooking Sydney Harbor. Buoyed by the companionship of a friendly but forgetful fish named Dory, the overly cautious Marlin embarks on a dangerous trek and finds himself the unlikely hero of an epic journey to rescue his son.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTY1MTg1NDAxOV5BMl5BanBnXkFtZTcwMjg1MDI5Nw@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/zjqInUwldOBa0q07fOyohYCWxWX.jpg',
#   u'rating': u'G',
#   u'revenue': 864625978,
#   u'score_imdb': 8.2,
#   u'score_metascore': 90,
#   u'score_rtcritics': 99,
#   u'title': u'Finding Nemo'},
#  {u'_id': u'iKTF64BQGnT2dQnxS',
#   u'actors': u'Clark Gable, Vivien Leigh, Olivia de Havilland, Leslie Howard, Hattie McDaniel',
#   u'directors': u'Victor Fleming, George Cukor',
#   u'genres': [u'Drama', u'Romance', u'War'],
#   u'plot': u'An American classic in which a manipulative woman and a roguish man carry on a turbulent love affair in the American south during the Civil War and Reconstruction.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNDUwMjAxNTU1MF5BMl5BanBnXkFtZTgwMzg4NzMxMDE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/2m9qsuDpAb6aBMxbKOBU1jsP9qf.jpg',
#   u'rating': u'G',
#   u'revenue': 400176459,
#   u'score_imdb': 8.2,
#   u'score_rtcritics': 95,
#   u'title': u'Gone with the Wind'},
#  {u'_id': u'fJ4n4sDvK9YjjohHo',
#   u'actors': u'Kay Panabaker, Rodger Bumpass, John Goodman, Billy Crystal, Mary Gibbs',
#   u'directors': u'Peter Docter, Pete Docter',
#   u'genres': [u'Comedy', u'Fantasy', u'Animation', u'Family'],
#   u'plot': u"James Sullivan and Mike Wazowski are monsters, they earn their living scaring children and are the best in the business... even though they're more afraid of the children than they are of them. When a child accidentally enters their world, James and Mike suddenly find that kids are not to be afraid of and they uncover a conspiracy that could threaten all children across the world.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTY1NTI0ODUyOF5BMl5BanBnXkFtZTgwNTEyNjQ0MDE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/93Y9BGx8blzmZOPSoivkFfaifqU.jpg',
#   u'rating': u'G',
#   u'revenue': 558523378,
#   u'score_imdb': 8.1,
#   u'score_metascore': 78,
#   u'score_rtcritics': 96,
#   u'title': u'Monsters, Inc.'},
#  {u'_id': u'HLMbcEtfpzTN5ph4d',
#   u'actors': u"Paige O'Hara, Robby Benson, Richard White, Jerry Orbach, David Ogden Stiers",
#   u'directors': u'Gary Trousdale, Bill Condon',
#   u'genres': [u'Romance', u'Fantasy', u'Animation', u'Music', u'Family'],
#   u'plot': u"Follow the adventures of Belle, a bright young woman who finds herself in the castle of a prince who's been turned into a mysterious beast. With the help of the castle's enchanted staff, Belle soon learns the most important lesson of all -- that true beauty comes from within.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTkyMDgwODY0OV5BMl5BanBnXkFtZTgwODI5NTQ5MTE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/b9QJr2oblOu1grgOMUZF1xkUJdh.jpg',
#   u'rating': u'G',
#   u'revenue': 377350553,
#   u'score_imdb': 8.1,
#   u'score_rtcritics': 93,
#   u'title': u'Beauty and the Beast'},
#  {u'_id': u'pwJsxnG7w3AWzGLFw',
#   u'actors': u'Charlton Heston, Jack Hawkins, Stephen Boyd, Haya Harareet, Martha Scott',
#   u'directors': u'William Wyler',
#   u'genres': [u'Action', u'Drama', u'Adventure', u'History'],
#   u'plot': u"Ben-Hur is a 1959 epic film directed by William Wyler, the third film version of Lew Wallace's 1880 novel Ben-Hur: A Tale of the Christ. It premiered at Loew's State Theatre in New York City on November 18, 1959. The film went on to win a record of eleven Academy Awards, including Best Picture, a feat equaled only by Titanic in 1998 and The Lord of the Rings: The Return of the King in 2004. It was also the last film to win the Oscar for both Best Actor and Best Supporting Actor, until nearly 44 years later when Mystic River achieved the same feat.The movie revolves around a Jewish prince who is betrayed and sent into slavery by a Roman friend and how he regains his freedom and comes back for revenge.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNjg2NjA3NDY2OV5BMl5BanBnXkFtZTgwNzE3NTkxMTE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/cNSBgQgJx2yXxYlIyWFhWz2F377.jpg',
#   u'rating': u'G',
#   u'revenue': 90000000,
#   u'score_imdb': 8.1,
#   u'score_rtcritics': 87,
#   u'title': u'Ben-Hur'},
#  {u'_id': u'Q9PX5GcxAYAmb7aYG',
#   u'actors': u'Patton Oswalt, Ian Holm, Lou Romano, Brian Dennehy, Peter Sohn',
#   u'directors': u'Brad Bird, Jan Pinkava',
#   u'genres': [u'Animation'],
#   u'plot': u"In one of Paris' finest restaurants, Remy, a determined young rat, dreams of becoming a renowned French chef. Torn between his family's wishes and his true calling. Remy and his pal Linguini set in motion a hilarious chain of events that turns the City of Lights upside down.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTMzODU0NTkxMF5BMl5BanBnXkFtZTcwMjQ4MzMzMw@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/wbG9OoWlkZ7QRyxfvpjdWUbfREX.jpg',
#   u'rating': u'G',
#   u'revenue': 623722164,
#   u'score_imdb': 8,
#   u'score_metascore': 96,
#   u'score_rtcritics': 96,
#   u'title': u'Ratatouille'},
#  {u'_id': u'r39soD74tv7oZfYjP',
#   u'actors': u'Robin Williams, Scott Weinger, Linda Larkin, Jonathan Freeman, Frank Welker',
#   u'directors': u'John Musker, Ron Clements',
#   u'genres': [u'Family',
#    u'Romance',
#    u'Fantasy',
#    u'Animation',
#    u'Adventure',
#    u'Comedy'],
#   u'plot': u'Princess Jasmine grows tired of being forced to remain in the palace and she sneaks out into the marketplace  in disguise where she meets street-urchin Aladdin and the two fall in love, although she may only marry a prince. After being thrown in jail, Aladdin and becomes embroiled in a plot to find a mysterious lamp with which the evil Jafar hopes to rule the land.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNTI4ODQ1MzAzNV5BMl5BanBnXkFtZTgwMzU4NzMxMDE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/oA2AY6adBYrHSrvMQSfZ14yA0HA.jpg',
#   u'rating': u'G',
#   u'revenue': 504050219,
#   u'score_imdb': 8,
#   u'score_rtcritics': 94,
#   u'title': u'Aladdin'},
#  {u'_id': u'j6zhtTnWSJpE3eFfT',
#   u'actors': u'Julie Andrews, Christopher Plummer, Eleanor Parker, Richard Haydn, Charmian Carr',
#   u'directors': u'Robert Wise',
#   u'genres': [u'Romance', u'Family', u'Drama', u'Music', u'War', u'History'],
#   u'plot': u"Rodgers and Hammerstein's The Sound of Music is a 1965 American musical film directed by Robert Wise and starring Julie Andrews and Christopher Plummer. The film is based on the Broadway musical The Sound of Music, with songs written by Richard Rodgers and Oscar Hammerstein II. It was photographed in 70mm Todd-AO by Ted D. McCord. It won a total of five Academy Awards including Best Picture in 1965 and is one of the most popular musicals ever produced. The cast album was nominated for a Grammy Award for Album of the Year. Adjusted for inflation, it made $1.046 billion domestically at 2010 prices, putting it third on the list of all-time inflation-adjusted box office hits, behind Gone with the Wind and Star Wars. The movie is based on a postulant nun, Maria, who leaves her Abbey to become a Governess to a retired Austrian Naval Captain and his 7 children.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTY0MzA3MDk2M15BMl5BanBnXkFtZTcwODg4MzEzMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/e06tZRg2xmqM3Q31x3Ln979dt0a.jpg',
#   u'rating': u'G',
#   u'revenue': 163214286,
#   u'score_imdb': 8,
#   u'score_rtcritics': 85,
#   u'title': u'The Sound of Music'},
#  {u'_id': u'KgreP5uY5bNqAHNWn',
#   u'actors': u'Patrick Stewart, James Earl Jones, The Berlin Philharmonic Orchestra, Paul McGann',
#   u'directors': u'Mark Linfield, Alastair Fothergill',
#   u'genres': [u'Documentary', u'Family'],
#   u'plot': u'From the acclaimed team that brought you BBC\'s visual feast "Planet Earth," this feature length film incorporates some of the same footage from the series with all new scenes following three remarkable, yet sadly endangered, families of animal across the globe.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTUwMzU5NDk3NF5BMl5BanBnXkFtZTcwOTM4MDUwMg@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/zXqVinbBdmSSqwQpnA0zT9o4GGM.jpg',
#   u'rating': u'G',
#   u'revenue': 109000000,
#   u'score_imdb': 8,
#   u'score_metascore': 72,
#   u'score_rtcritics': 87,
#   u'title': u'Earth'},
#  {u'_id': u'rN79i9PgNuFyndWKB',
#   u'actors': u'Charlton Heston, Roddy McDowall, Kim Hunter, Maurice Evans, James Whitmore',
#   u'directors': u'Franklin J. Schaffner',
#   u'genres': [u'Mystery', u'Science Fiction', u'Adventure'],
#   u'plot': u'Taylor and two other astronauts come out of deep hibernation to find that their ship has crashed. Escaping with little more than clothes they find that they have landed on a planet where men are pre-lingual and uncivilized while apes have learned speech and technology. Taylor is captured and taken to the city of the apes after damaging his throat so that he is silent and cannot communicate with the apes.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTg0NjUwMzg5NF5BMl5BanBnXkFtZTgwNDQ0NjcwMTE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/ktS3v2OfBouSiDDA3tQsrjidt5i.jpg',
#   u'rating': u'G',
#   u'revenue': 33395426,
#   u'score_imdb': 8,
#   u'score_rtcritics': 89,
#   u'title': u'Planet of the Apes'},
#  {u'_id': u'KxCJWT55ryRwyR5TK',
#   u'actors': u'Rod Steiger, Sidney Poitier, Warren Oates, Lee Grant, James Patterson',
#   u'directors': u'Norman Jewison',
#   u'genres': [u'Drama', u'Mystery', u'Thriller', u'Crime'],
#   u'plot': u'An African American detective is asked to investigate a murder in a racist southern town.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTk3NjkxMDc1MV5BMl5BanBnXkFtZTcwMDIwMjI0NA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/w3S3UHDpoEYiNjXgULwmbJ5ZWVa.jpg',
#   u'rating': u'G',
#   u'revenue': 27379978,
#   u'score_imdb': 8,
#   u'score_rtcritics': 94,
#   u'title': u'In the Heat of the Night'},
#  {u'_id': u'vpesf36CYd3vbEQQE',
#   u'actors': u'Mickey Mouse, Wayne Allwine, Will Ryan, Patricia Parris, Clarence Nash',
#   u'directors': u'Burny Mattinson',
#   u'genres': [u'Animation', u'Family'],
#   u'plot': u"It is an adaptation of the Charles Dickens classic A Christmas Carol, featuring Scrooge McDuck as his namesake and inspiration Ebenezer Scrooge and Mickey Mouse as Bob Cratchit. This film was based on a 1972 audio musical entitled Disney's A Christmas Carol. It is a twenty-four minute animated short film produced by Walt Disney Productions as an accompaniment to a re-release of The Rescuers.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjEzNTM4NzE2N15BMl5BanBnXkFtZTcwODM3ODcxMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/b5bOnImybMdWNA415PXFjMWlsi7.jpg',
#   u'rating': u'G',
#   u'revenue': 21000000,
#   u'score_imdb': 8,
#   u'title': u"Mickey's Christmas Carol"},
#  {u'_id': u'FGaLaAeP2GMtg3xSD',
#   u'actors': u'Jacques Perrin, Philippe Labro',
#   u'directors': u'Jacques Cluzard, Jacques Perrin',
#   u'genres': [u'Documentary'],
#   u'plot': u"The cameras of Jacques Perrin fly with migratory birds: geese, storks, cranes. The film begins with spring in North America and the migration to the Arctic; the flight is a community event for each species. Once in the Arctic, it's family time: courtship, nests, eggs, fledglings, and first flight. Chicks must soon fly south. Bad weather, hunters, and pollution take their toll. Then, the cameras go",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTkwOTg5MTI5N15BMl5BanBnXkFtZTYwNTQ3Njk5._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/qY1l18Zri3Mdc0iBr0QYjCWlFVP.jpg',
#   u'rating': u'G',
#   u'revenue': 20217080,
#   u'score_imdb': 8,
#   u'score_metascore': 82,
#   u'score_rtcritics': 96,
#   u'title': u'Winged Migration'},
#  {u'_id': u'T8YeCpP9pTda7EB6W',
#   u'actors': u'Cary Grant, Audrey Hepburn, Walter Matthau, James Coburn, George Kennedy',
#   u'directors': u'Stanley Donen',
#   u'genres': [u'Mystery', u'Romance', u'Comedy', u'Thriller'],
#   u'plot': u'Romance and suspense in Paris, as a woman is pursued by several men who want a fortune her murdered husband had stolen. Who can she trust?',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNTIwODUwMjU1N15BMl5BanBnXkFtZTgwMzg4ODQwMjE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/usONLH3H7TQnlJSck81pPalXoys.jpg',
#   u'rating': u'G',
#   u'revenue': 13474588,
#   u'score_imdb': 8,
#   u'score_rtcritics': 92,
#   u'title': u'Charade'},
#  {u'_id': u'R3ZAnwELZ7dbRZBcH',
#   u'actors': u'Fay Wray, Robert Armstrong, Bruce Cabot, Sam Hardy, Frank Reicher',
#   u'directors': u'Ernest B. Schoedsack, Merian C. Cooper',
#   u'genres': [u'Action', u'Drama', u'Horror', u'Adventure', u'Thriller'],
#   u'plot': u'An adventure film about a film crew in search of a monster on a remote island. The crew finds King Kong and decides to take him back to New York as a money making spectacle. The film is a masterpiece of Stop-Motion in filmmaking history and inspired a line of King Kong films.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BODM0MTEyMjQxOF5BMl5BanBnXkFtZTgwNzYwNTk1MjE@._V1._CR8.883331298828125,6.5333404541015625,344,488_SY132_CR2,0,89,132_AL_.jpg_V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/b1FzD0WxnfhkIbjxwFOKJHUuEsH.jpg',
#   u'rating': u'G',
#   u'revenue': 10000000,
#   u'score_imdb': 8,
#   u'score_rtcritics': 98,
#   u'title': u'King Kong'},
#  {u'_id': u'oxd5Spk4XJQ529FEw',
#   u'actors': u'Wayne Knights, Tom Hanks, Tim Allen, Joan Cusack, Kelsey Grammer',
#   u'directors': u'Ash Brannon, John Lasseter',
#   u'genres': [u'Comedy', u'Animation', u'Family'],
#   u'plot': u'During a garage sale Andy\u2019s mother sells some of Andy\u2019s old things including his favorite toy Woody to a collector. Buzz Lightyear and the other toys begin a reckless mission to save their friend. The sequel to the revolutionary computer animated feature film Toy Story.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTQ0OTU0NTcyNl5BMl5BanBnXkFtZTcwOTk5Mjc4OA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/gd12nM0VnrgbaUmZDjte4oBedGZ.jpg',
#   u'rating': u'G',
#   u'revenue': 485015179,
#   u'score_imdb': 7.9,
#   u'score_metascore': 88,
#   u'score_rtcritics': 100,
#   u'title': u'Toy Story 2'},
#  {u'_id': u'uWoPEwcddcLHZxwRh',
#   u'actors': u'Charlton Heston, Yul Brynner, Anne Baxter, Edward G. Robinson, Yvonne De Carlo',
#   u'directors': u'Cecil B. De Mille, Cecil B. DeMille',
#   u'genres': [u'Drama', u'History'],
#   u'plot': u'Escaping death, a Hebrew infant is raised in a royal household to become a prince. Upon discovery of his true heritage, Moses embarks on a personal quest to reclaim his destiny as the leader and liberator of the Hebrew people.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTQ1NjQ4MjQyOF5BMl5BanBnXkFtZTgwMjMzODgyMTE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/t6knlykGSL9pjqBrK2J6n9mUyIH.jpg',
#   u'rating': u'G',
#   u'revenue': 65000000,
#   u'score_imdb': 7.9,
#   u'score_rtcritics': 91,
#   u'title': u'The Ten Commandments'},
#  {u'_id': u'3YHmY3JMX8HsnL82c',
#   u'actors': u'Donald Barclay, Julie Andrews, Dick Van Dyke, Glynis Johns, David Tomlinson',
#   u'directors': u'Robert Stevenson',
#   u'genres': [u'Fantasy', u'Comedy', u'Music', u'Family'],
#   u'plot': u'The movie combines a diverting story, songs, color and sequences of live action blended with the movements of animated figures. Mary Poppins is a kind of Super-nanny who flies in with her umbrella in response to the request of the Banks children and proceeds to put things right with the aid of her rather extraordinary magical powers before flying off again.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTY1MDQwNTM3Ml5BMl5BanBnXkFtZTgwNzA3ODg3MDE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/A8LtO46RpTpn6K54SugowckB7Uw.jpg',
#   u'rating': u'G',
#   u'revenue': 102272727,
#   u'score_imdb': 7.8,
#   u'score_rtcritics': 100,
#   u'title': u'Mary Poppins'},
#  {u'_id': u'wK5j9ndZi9inkqqFP',
#   u'actors': u'Deems Taylor, Philadelphia Symphony Orchestra, Bela Lugosi',
#   u'directors': u'T. Hee, Bianca Majolie',
#   u'genres': [u'Fantasy', u'Animation', u'Music', u'Family'],
#   u'plot': u'Fantasia is the adventurous 1940 experiment from Disney. The film sets Disney animated characters to classical music as Mickey Mouse uses his magic wand to set broomsticks dancing in one of the more famous elaborate scenes. The film was groundbreaking in its usage of animation and music and is still considered a masterpiece decades later.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTM2Nzk5ODU5NF5BMl5BanBnXkFtZTcwMjQ1ODYxMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/9YXyiRszikyoakc4oNaHbjjybmT.jpg',
#   u'rating': u'G',
#   u'revenue': 76000000,
#   u'score_imdb': 7.8,
#   u'score_rtcritics': 96,
#   u'title': u'Fantasia'},
#  {u'_id': u'EC7guWQ3KKMK3wZJo',
#   u'actors': u'Burt Lancaster, Montgomery Clift, Deborah Kerr, Frank Sinatra, Donna Reed',
#   u'directors': u'Fred Zinnemann',
#   u'genres': [u'Drama', u'Romance', u'War'],
#   u'plot': u"The setting is an army base in Hawaii in 1941. Montgomery Clift, in a superb performance, plays a bugler who refuses to fight for the company boxing team; he has reasons for giving up the sport. His refusal results in harsh treatment from the company commander, whose bored wife (Deborah Kerr) is having an affair with the tough-but-fair sergeant (Burt Lancaster). You remember--the scene with the two of them embracing on the beach, as the surf crashes in. The supporting players are as good as the leads: Frank Sinatra and Donna Reed won Oscars (and Sinatra revitalized his entire career), and Ernest Borgnine entered the gallery of all-time movie villains, as the stockade sergeant who makes Sinatra miserable. Zinnemann's work is efficient but also evocative, capturing the time and place beautifully, the tropical breezes as well as the lazy prewar indulgence. This one is deservedly a classic. --Robert Horton",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTI5MDk2ODc2M15BMl5BanBnXkFtZTYwNDQ2NDE5._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/bvWfIi0ZLeX4yaCH5rQWRiOT4aT.jpg',
#   u'rating': u'G',
#   u'revenue': 30500000,
#   u'score_imdb': 7.8,
#   u'score_rtcritics': 89,
#   u'title': u'From Here to Eternity'},
#  {u'_id': u'Tek32XGK4ko2KtLhj',
#   u'actors': u'Lancelot Perrin, Pierce Brosnan',
#   u'directors': u'Jacques Cluzaud, Jacques Perrin',
#   u'genres': [u'Documentary', u'Family'],
#   u'plot': u'An ecological drama/documentary, filmed throughout the globe. Part thriller, part meditation on the vanishing wonders of the sub-aquatic world.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjEzMTQxMjIyMF5BMl5BanBnXkFtZTcwODM4MTUyMw@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/cnkOrknvytbeMa0iAoTa48lZz37.jpg',
#   u'rating': u'G',
#   u'revenue': 19406406,
#   u'score_imdb': 7.8,
#   u'score_metascore': 75,
#   u'score_rtcritics': 81,
#   u'title': u'Oceans'},
#  {u'_id': u'JcpCM92F2Yhpty9zJ',
#   u'actors': u'Yuria Nara, Hiroki Doi, Tomoko Yamaguchi, Kazushige Nagashima, George Tokoro',
#   u'directors': u'Hayao Miyazaki',
#   u'genres': [u'Animation', u'Adventure', u'Family'],
#   u'plot': u"The son of a sailor, 5-year old Sosuke lives a quiet life on an oceanside cliff with his mother Lisa. One fateful day, he finds a beautiful goldfish trapped in a bottle on the beach and upon rescuing her, names her Ponyo. But she is no ordinary goldfish. The daughter of a masterful wizard and a sea goddess, Ponyo uses her father's magic to transform herself into a young girl and quickly falls in love with Sosuke, but the use of such powerful sorcery causes a dangerous imbalance in the world. As the moon steadily draws nearer to the earth and Ponyo's father sends the ocean's mighty waves to find his daughter, the two children embark on an adventure of a lifetime to save the world and fulfill Ponyo's dreams of becoming human.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjA5NzkxNTg2MF5BMl5BanBnXkFtZTcwMTA3MjU1Mg@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/tg7Z7rCzncljHlAONch3dmpxy4s.jpg',
#   u'rating': u'G',
#   u'revenue': 187479518,
#   u'score_imdb': 7.7,
#   u'score_metascore': 86,
#   u'score_rtcritics': 92,
#   u'title': u'Ponyo'},
#  {u'_id': u'oFv5vRcPqeFK3Cj7J',
#   u'actors': u'Bridgit Mendler, Amy Poehler, Will Arnett, Carol Burnett, David Henrie',
#   u'directors': u'Hiromasa Yonebayashi, Atsushi Okui',
#   u'genres': [u'Fantasy', u'Animation', u'Family'],
#   u'plot': u'14-year-old Arrietty and the rest of the Clock family live in peaceful anonymity as they make their own home from items "borrowed" from the house\'s human inhabitants. However, life changes for the Clocks when a human boy discovers Arrietty.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTAxNjk3OTYyODReQTJeQWpwZ15BbWU3MDgyODY2OTY@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/A4w9oSNQUwtkaucy3K7LbSngKrk.jpg',
#   u'rating': u'G',
#   u'revenue': 148202743,
#   u'score_imdb': 7.7,
#   u'score_metascore': 80,
#   u'score_rtcritics': 95,
#   u'title': u'The Secret World of Arrietty'},
#  {u'_id': u'5oqk6aPFgw6Fdo9D5',
#   u'actors': u'Morgan Freeman, Charles Berling, Ching-wen Chia, Hikari Ishida, Jules Sitruk',
#   u'directors': u'Luc Jacquet',
#   u'genres': [u'Documentary', u'Family'],
#   u'plot': u"Every year, thousands of Antartica's emperor penguins make an astonishing journey to breed their young. They walk, marching day and night in single file 70 miles into the darkest, driest and coldest continent on Earth. Morgan Freeman narrates this amazing tale, Breathtaking photography captures the transcendaent beauty and staggering drama, so follow the leader.. to adventure!",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTM1NDc5MDYxMl5BMl5BanBnXkFtZTcwMjMzNDAzMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/yjAayG6nY9VO8IJoTLrSLUyu5kD.jpg',
#   u'rating': u'G',
#   u'revenue': 127392239,
#   u'score_imdb': 7.7,
#   u'score_metascore': 79,
#   u'score_rtcritics': 94,
#   u'title': u'March of the Penguins'},
#  {u'_id': u'obG9FSjpuuorkg78k',
#   u'actors': u'The Muppets, Austin Pendleton, Dom DeLuise, Steve Martin, Mel Brooks',
#   u'directors': u'James Frawle, James Frawley',
#   u'genres': [u'Comedy', u'Adventure', u'Family'],
#   u'plot': u'Kermit the Frog is persuaded by agent Dom DeLuise to pursue a career in Hollywood. Along the way, Kermit picks up Fozzie Bear, Miss Piggy, Gonzo, and a motley crew of other Muppets with similar aspirations. Meanwhile, Kermit must elude the grasp of a frog-leg restaurant magnate.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTgzOTg2MTM3M15BMl5BanBnXkFtZTcwMzgxMzEzMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/48Ve7uLDcPJFGaDnmYYdcV3Ve1M.jpg',
#   u'rating': u'G',
#   u'revenue': 76657000,
#   u'score_imdb': 7.7,
#   u'score_metascore': 69,
#   u'score_rtcritics': 89,
#   u'title': u'The Muppet Movie'},
#  {u'_id': u'YLTuJkrY63jBgonxR',
#   u'actors': u'Elizabeth Taylor, Rock Hudson, James Dean, Mercedes McCambridge, Carroll Baker',
#   u'directors': u'George Stevens, George Stevens Jr.',
#   u'genres': [u'Action', u'Drama', u'Western'],
#   u'plot': u'Sprawling epic covering the life of a Texas cattle rancher and his family and associates.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjAwMTg5NjA3MV5BMl5BanBnXkFtZTgwOTQ4NzMxMDE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/l2PBOEbCxF5bDxP7hN1r9XjrQjp.jpg',
#   u'rating': u'G',
#   u'revenue': 35000000,
#   u'score_imdb': 7.7,
#   u'score_rtcritics': 95,
#   u'title': u'Giant'},
#  {u'_id': u'euHFnB2ozWecFmonN',
#   u'actors': u'The Muppets, Michael Caine, Rob Tygner, Karen Prell, Jessica Fox',
#   u'directors': u'Brian Henson',
#   u'genres': [u'Drama', u'Fantasy', u'Comedy', u'Family'],
#   u'plot': u'A retelling of the classic Dickens tale of Ebenezer Scrooge, miser extraordinaire. He is held accountable for his dastardly ways during night-time visitations by the Ghosts of Christmas Past, Present, and future.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjA3NzE5NzczOV5BMl5BanBnXkFtZTgwNzc1Njc1MzE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/fe4nLJkDNXhyuMnrZ60MfoSpPes.jpg',
#   u'rating': u'G',
#   u'revenue': 27281507,
#   u'score_imdb': 7.7,
#   u'score_rtcritics': 69,
#   u'title': u'The Muppet Christmas Carol'},
#  {u'_id': u'YCAWqxR3DTFbA6TXm',
#   u'actors': u'Walter Pidgeon, Anne Francis, Leslie Nielsen, Warren Stevens, Jack Kelly',
#   u'directors': u'Fred McLeod Wilcox, Fred M. Wilcox',
#   u'genres': [u'Science Fiction'],
#   u'plot': u'Captain Adams and the crew of the Starship C57D fly towards planet Altair 4 in search for the Bellerphon spaceship that has been missing for twenty years. To their surprise they are already being expected. A classic science fiction film from 1957 starring Leslie Nielsen.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTMxOTc2NzgxMF5BMl5BanBnXkFtZTcwNzYxNDcyMg@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/qdH1Fm5vl1DAjXNHPmRZ4yEiUgM.jpg',
#   u'rating': u'G',
#   u'revenue': 23500000,
#   u'score_imdb': 7.7,
#   u'score_rtcritics': 98,
#   u'title': u'Forbidden Planet'},
#  {u'_id': u'ERhLoFF2iNnheZm8R',
#   u'actors': u'Alan Ladd, Jean Arthur, Van Heflin, Brandon De Wilde, Jack Palance',
#   u'directors': u'George Stevens, George Stevens Jr.',
#   u'genres': [u'Drama', u'Western'],
#   u'plot': u'A weary gunfighter attempts to settle down with a homestead family, but a smouldering settler and rancher conflict forces him to act.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTM0Nzg5NzE5Ml5BMl5BanBnXkFtZTcwNzE3NDkyMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/cygZtY0h27nk1612ElBwt7CXYwc.jpg',
#   u'rating': u'G',
#   u'revenue': 20000000,
#   u'score_imdb': 7.7,
#   u'score_rtcritics': 97,
#   u'title': u'Shane'},
#  {u'_id': u'Pfuqy3pXhx8GFQ2g2',
#   u'actors': u'Sam E. Wright, Philip L. Clarke, Gloria Grace Prosper, Gerrit Graham, Jodi Benson',
#   u'directors': u'John Musker, Buddy Hackett',
#   u'genres': [u'Animation', u'Family'],
#   u'plot': u'This colorful adventure tells the story of an impetuous mermaid princess named Ariel who falls in love with the very human Prince Eric and puts everything on the line for the chance to be with him. Memorable songs and characters -- including the villainous sea witch Ursula.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNTAxMzY0MjI1Nl5BMl5BanBnXkFtZTgwMTU2NTYxMTE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/ujlSe3lhp1OKmF2LNu6wRpWbdiU.jpg',
#   u'rating': u'G',
#   u'revenue': 211343479,
#   u'score_imdb': 7.6,
#   u'score_rtcritics': 92,
#   u'title': u'The Little Mermaid'},
#  {u'_id': u'szH43y8K4F23scjtz',
#   u'actors': u'Helena Bonham Carter, Peter Sallis, Ralph Fiennes, John Thomson, Peter Kay',
#   u'directors': u'Steve Box, Nick Park',
#   u'genres': [u'Comedy', u'Animation', u'Adventure', u'Family'],
#   u'plot': u"Cheese-loving eccentric Wallace and his cunning canine pal, Gromit, investigate a mystery in Nick Park's animated adventure, in which the lovable inventor and his intrepid pup run a business ridding the town of garden pests. Using only humane methods that turn their home into a halfway house for evicted vermin, the pair stumble upon a mystery involving a voracious vegetarian monster that threatens to ruin the annual veggie-growing contest.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTk1NzIwNTM1NV5BMl5BanBnXkFtZTcwMDA1NzkyMw@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/tLryx0x9TDV5rifA9W8yUvDZFHB.jpg',
#   u'rating': u'G',
#   u'revenue': 192452832,
#   u'score_imdb': 7.6,
#   u'score_metascore': 87,
#   u'score_rtcritics': 95,
#   u'title': u'Wallace & Gromit: The Curse of the Were-Rabbit'},
#  {u'_id': u'4XDWhhnzWdRC6rFzt',
#   u'actors': u'Dick Jones, Mel Blanc, Cliff Edwards, Christian Rub, Walter Catlett',
#   u'directors': u'Norman Ferguson, Bill Roberts',
#   u'genres': [u'Animation', u'Family'],
#   u'plot': u'Lonely toymaker Geppetto has his wishes answered when the Blue Fairy arrives to bring his wooden puppet Pinocchio to life. Before becoming a real boy, however, Pinocchio must prove he\'s worthy as he sets off on an adventure with his whistling sidekick and conscience, Jiminy Cricket. From Stromboli\'s circus to Pleasure Island, Pinocchio is tested by many temptations, but slowly learns how to navigate right from wrong. With a few mishaps along the way, Geppetto\'s "little woodenhead" finally gets it right, proving that when you wish upon a star dreams really can come true!',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTI0Nzk1NTQ2Ml5BMl5BanBnXkFtZTcwNjgyNDIzMg@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/6zMvTPuyZ1slwaxVijzsQRLVcdq.jpg',
#   u'rating': u'G',
#   u'revenue': 84300000,
#   u'score_imdb': 7.6,
#   u'score_rtcritics': 100,
#   u'title': u'Pinocchio'},
#  {u'_id': u'AhGgHKa43vKbp2Hq6',
#   u'actors': u'Candy Candido, John Fiedler, Dana Laurita, Barbara Luddy, Brian Bedford',
#   u'directors': u'Wolfgang Reitherman',
#   u'genres': [u'Animation', u'Family'],
#   u'plot': u"With King Richard off to the Crusades, Prince John and his slithering minion, Sir Hiss, set about taxing Nottingham's citizens with support from the corrupt sheriff - and staunch opposition by the wily Robin Hood and his band of merry men.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjE2MjI0NjQ3Ml5BMl5BanBnXkFtZTcwMDk5ODczMQ@@._V1._CR0,34,352,463_SY132_CR5,0,89,132_AL_.jpg_V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/78yFcKivWbLwlPcUOPj2A75k4Ii.jpg',
#   u'rating': u'G',
#   u'revenue': 32056467,
#   u'score_imdb': 7.6,
#   u'score_rtcritics': 52,
#   u'title': u'Robin Hood'},
#  {u'_id': u'FXK4cezBbHBPEdYKT',
#   u'actors': u'Paul Shenar, Jodi Hicks, Ian Fried, Tom Hatten, Lucille Bliss',
#   u'directors': u'Don Bluth',
#   u'genres': [u'Drama', u'Fantasy', u'Animation', u'Family'],
#   u'plot': u"A widowed field mouse must move her family -- including an ailing son -- to escape a farmer's plow. Aided by a crow and a pack of superintelligent, escaped lab rats, the brave mother struggles to transplant her home to firmer ground.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNTEwMDEyNzI2OV5BMl5BanBnXkFtZTcwNTAxMDc2NA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/qXvgbM2cIjkoOPgzxn0hwiSUqk6.jpg',
#   u'rating': u'G',
#   u'revenue': 14665733,
#   u'score_imdb': 7.6,
#   u'score_rtcritics': 96,
#   u'title': u'The Secret of NIMH'},
#  {u'_id': u'CbMkMyDr3K9YsLaYf',
#   u'actors': u'Miguel Ferrer, Soon-Teck Oh, Miriam Margolyes, James Shigeta, Freda Foh Shen',
#   u'directors': u'Barry Cook, Tony Bancroft',
#   u'genres': [u'Animation', u'Adventure', u'Family'],
#   u'plot': u'A tomboyish girl disguises herself as a young man so she can fight with the Imperial Chinese Army against the invading Huns. With help from wise-cracking dragon Mushu, Mulan just might save her country -- and win the heart of handsome Captain Li Shang.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTIwNjY4NDU2NF5BMl5BanBnXkFtZTcwMzM0OTUyMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/ztD0iLfeyESQZV95GwPeSE3Uyqn.jpg',
#   u'rating': u'G',
#   u'revenue': 304320254,
#   u'score_imdb': 7.5,
#   u'score_metascore': 71,
#   u'score_rtcritics': 86,
#   u'title': u'Mulan'},
#  {u'_id': u'MRjAhsCxPdEjwruTj',
#   u'actors': u'Eijir Tono, Ned Wertimer, S Yamamura, Martin Balsam, Jason Robards',
#   u'directors': u'Richard Fleischer, Kinji Fukasaku',
#   u'genres': [u'Action', u'Drama', u'Adventure', u'War'],
#   u'plot': u'In the summer of 1941, the United States and Japan seem on the brink of war after constant embargos and failed diplomacy come to no end. "Tora! Tora! Tora!", named after the code words use by the lead Japanese pilot to indicate they had surprised the Americans, covers the days leading up to the attack on Pearl Harbor, which plunged America into the Second World War.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTI4NjgwOTIzN15BMl5BanBnXkFtZTYwNjU1MzE5._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/vBxZpSulJCNNH5VonyUjZHaDJek.jpg',
#   u'rating': u'G',
#   u'revenue': 29548291,
#   u'score_imdb': 7.5,
#   u'score_rtcritics': 59,
#   u'title': u'Tora! Tora! Tora!'},
#  {u'_id': u'SQGqGoij6ibp3m7mG',
#   u'actors': u'Deborah Kerr, Yul Brynner, Martin Benson, Rita Moreno, Terry Saunders',
#   u'directors': u'Walter Lang',
#   u'genres': [u'Drama', u'Romance', u'Family'],
#   u'plot': u'Mrs. Anna Leonowens and her son Louis arrive in Bangkok, where she has contracted to teach English to the children of the royal household. She threatens to leave when the house she had been promised is not available, but falls in love with the children. A new slave, a gift of a vassal king, translates "Uncle Tom\'s Cabin" into a Siamese ballet, expressing her unhappiness at being with the King. She attempts to escape with her lover. Anna and the King fall in love, but her British upbringing inhibits her from joining his harem. She is just about to leave Siam when she hears of the King\'s imminent death, and returns to help his son, her favorite pupil, rule his people.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTI5MDkzMzYzMV5BMl5BanBnXkFtZTcwMzA5NTczMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/4nXQ4TpMw2uacbB4eFlvQMl7VB0.jpg',
#   u'rating': u'G',
#   u'revenue': 21300000,
#   u'score_imdb': 7.5,
#   u'score_rtcritics': 96,
#   u'title': u'The King and I'},
#  {u'_id': u'tng8aayRECWEt7Wa2',
#   u'actors': u'Samuel L. Jackson',
#   u'directors': u'Alastair Fothergill, Keith Scholey',
#   u'genres': [u'Documentary', u'Adventure', u'Family'],
#   u'plot': u'African Cats captures the real-life love, humor and determination of the majestic kings of the savanna. The story features Mara, an endearing lion cub who strives to grow up with her mother\u2019s strength, spirit and wisdom; Sita, a fearless cheetah and single mother of five mischievous newborns; and Fang, a proud leader of the pride who must defend his family from a once banished lion.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTYxOTQ3MjM5OV5BMl5BanBnXkFtZTcwMDYzMjAyNA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/3exZKtP0r88MhP12HeTgp4uiVRu.jpg',
#   u'rating': u'G',
#   u'revenue': 15240456,
#   u'score_imdb': 7.5,
#   u'score_metascore': 61,
#   u'score_rtcritics': 71,
#   u'title': u'African Cats'},
#  {u'_id': u'uaZGeYAjvRCkhrmy2',
#   u'actors': u'Helen Mirren, Sean Hayes, Alfred Molina, Tyler Labine, Nathan Fillion',
#   u'directors': u'Dan Scanlon',
#   u'genres': [u'Animation'],
#   u'plot': u"A look at the relationship between Mike and Sulley during their days at Monsters University \u2014 when they weren't necessarily the best of friends.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTUyODgwMDU3M15BMl5BanBnXkFtZTcwOTM4MjcxOQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/flXrt9Dh0Tki6zOgX0TOq63KpG8.jpg',
#   u'rating': u'G',
#   u'revenue': 743559607,
#   u'score_imdb': 7.4,
#   u'score_metascore': 65,
#   u'score_rtcritics': 78,
#   u'title': u'Monsters University'},
#  {u'_id': u'NPSwbyhqPC4MdSASm',
#   u'actors': u"Jerry Colonna, Verna Felton, Pat O'Malley, Heather Angel, Joseph Kearns",
#   u'directors': u'Clyde Geronimi, Wilfred Jackson',
#   u'genres': [u'Animation', u'Family'],
#   u'plot': u"On a golden afternoon, young Alice follows a White Rabbit, who disappears down a nearby rabbit hole. Quickly following him, she tumbles into the burrow - and enters the merry, topsy-turvy world of Wonderland! Memorable songs and whimsical escapades highlight Alice's journey, which culminates in a madcap encounter with the Queen of Hearts - and her army of playing cards!",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTgyMjM2NTAxMF5BMl5BanBnXkFtZTgwNjU1NDc2MTE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/ybKlGYsLYUUxIl0xdZsm37nHYtR.jpg',
#   u'rating': u'G',
#   u'revenue': 572000000,
#   u'score_imdb': 7.4,
#   u'score_rtcritics': 78,
#   u'title': u'Alice in Wonderland'},
#  {u'_id': u'QRth8p4X4ycyQbzZv',
#   u'actors': u'Hardy Albright, Paul Behn, Bambi, Hardie Albright, Tim Davis',
#   u'directors': u'Graham Heid, Perce Pearce',
#   u'genres': [u'Drama', u'Animation', u'Family'],
#   u'plot': u"The animated story of Bambi, a young deer hailed as the 'Prince of the Forest' at his birth. As Bambi grows, he makes friends with the other animals of the forest, learns the skills needed to survive, and even finds love. One day, however, the hunters come, and Bambi must learn to be as brave as his father if he is to lead the other deer to safety.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTY1NzM4NDg5MV5BMl5BanBnXkFtZTgwMjI1MTkzMjE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/laABfcpEKweQsaZwCWzmGNUpij9.jpg',
#   u'rating': u'G',
#   u'revenue': 267447150,
#   u'score_imdb': 7.4,
#   u'score_rtcritics': 91,
#   u'title': u'Bambi'},
#  {u'_id': u'QErFqphHf22HapinK',
#   u'actors': u'Barbara Luddy, Larry Roberts, Bill Thompson, Stan Freberg, Verna Felton',
#   u'directors': u'Barbara Luddy, Bill Baucom',
#   u'genres': [u'Animation', u'Family'],
#   u'plot': u"Lady, a golden cocker spaniel, meets up with a mongrel dog who calls himself the Tramp. He is obviously from the wrong side of town, but happenings at Lady's home make her decide to travel with him for a while.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjAwNzA3NTk0NV5BMl5BanBnXkFtZTcwMzkyNDEzMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/kpfbF0C0lSvvKE3JQVuAGufA6UT.jpg',
#   u'rating': u'G',
#   u'revenue': 93600000,
#   u'score_imdb': 7.4,
#   u'score_rtcritics': 89,
#   u'title': u'Lady and the Tramp'},
#  {u'_id': u'2S8ZKWNLJcsWXfXoW',
#   u'actors': u'Barbara Jo Allen, Pinto Colvig, Dal McKennon, Marvin Miller, Mary Costa',
#   u'directors': u'Eric Larson (II), Les Clark',
#   u'genres': [u'Romance', u'Fantasy', u'Animation', u'Family'],
#   u'plot': u"A beautiful princess born in a faraway kingdom is destined by a terrible curse to prick her finger on the spindle of a spinning wheel and fall into a deep sleep that can only be awakened by true love's first kiss. Determined to protect her, her parents ask three fairies to raise her in hiding. But the evil Maleficent is just as determined to seal the princess's fate.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjExODM3ODMyMF5BMl5BanBnXkFtZTcwNjg4MzM2MQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/6MbrpfW1CYmneQ8nBohauWtLWA3.jpg',
#   u'rating': u'G',
#   u'revenue': 51000000,
#   u'score_imdb': 7.4,
#   u'score_rtcritics': 92,
#   u'title': u'Sleeping Beauty'},
#  {u'_id': u'uGRsHRfRBvYLNT4Rg',
#   u'actors': u'Roland DuPree, Don Barclay, Bobby Driscoll, Kathryn Beaumont, Hans Conried',
#   u'directors': u'Wilfred Jackson, Clyde Geronimi',
#   u'genres': [u'Fantasy', u'Animation', u'Music', u'Adventure', u'Family'],
#   u'plot': u'Leaving the safety of their nursery behind, Wendy, Michael and John follow Peter Pan to a magical world where childhood lasts forever. But while in Neverland, the kids must face Captain Hook and foil his attempts to get rid of Peter for good.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNzQ3OTU3ODA3Nl5BMl5BanBnXkFtZTcwNzYwODk3OA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/n69umC19fsIKXlQBm0eD6waSwpI.jpg',
#   u'rating': u'G',
#   u'revenue': 29445131,
#   u'score_imdb': 7.4,
#   u'score_rtcritics': 75,
#   u'title': u'Peter Pan'},
#  {u'_id': u'Jc8nepmmLKQ2bmynF',
#   u'actors': u'John Wayne, Kim Darby, Glen Campbell, Robert Duvall, Jeremy Slate',
#   u'directors': u'Henry Hathaway',
#   u'genres': [u'Western'],
#   u'plot': u'The murder of her father sends a teenage tomboy, Mattie Ross (Kim Darby), on a mission of "justice", which involves avenging her father\'s death. She recruits a tough old marshal, "Rooster" Cogburn (John Wayne), because he has "grit", and a reputation of getting the job done. The two are joined by a Texas Ranger, La Boeuf (Glen Campbell), who is looking for the same man (Jeff Corey) for a separate murder in Texas. Their odyssey takes them from Fort Smith, Arkansas, deep into the Indian Territory (present day Oklahoma) to find their man.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTYwNTE3NDYzOV5BMl5BanBnXkFtZTcwNTU5MzY0MQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/vAdUFsAUTEWep58MRduS1ivS2vP.jpg',
#   u'rating': u'G',
#   u'revenue': 14250000,
#   u'score_imdb': 7.4,
#   u'score_rtcritics': 90,
#   u'title': u'True Grit'},
#  {u'_id': u'jf7axCtujBMCHu9xS',
#   u'actors': u"Charlie Chaplin, Paulette Goddard, Henry Bergman, Stanley J. ('Tiny') Sandford, Chester Conklin",
#   u'directors': u'Charlie Chaplin, Charles Chaplin',
#   u'genres': [u'Drama', u'Comedy'],
#   u'plot': u'The Tramp struggles to live in modern industrial society with the help of a young homeless woman.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjAyMTkxNjI5OF5BMl5BanBnXkFtZTYwMjI2MjA5._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/rHkLAGAo8j3MOYOVupwn4fafVBt.jpg',
#   u'rating': u'G',
#   u'revenue': 8500000,
#   u'score_imdb': 8.6,
#   u'score_metascore': 96,
#   u'score_rtcritics': 100,
#   u'title': u'Modern Times'},
#  {u'_id': u'XxwxjxGwS3RRZXgWs',
#   u'actors': u'David Spade, John Goodman, Eartha Kitt, Patrick Warburton, Wendie Malick',
#   u'directors': u'Mark Dindal',
#   u'genres': [u'Comedy', u'Fantasy', u'Animation', u'Adventure', u'Family'],
#   u'plot': u"Kuzco is a self-centered emperor who summons Pacha from a village and to tell him that his home will be destroyed to make room for Kuzco's new summer home. Kuzco's advisor, Yzma, tries to poison Kuzco and accidentally turns him into a llama, who accidentally ends up in Pacha's village. Pacha offers to help Kuzco if he doesn't destroy his house, and so they form an unlikely partnership.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTMxNTY0MzU1MV5BMl5BanBnXkFtZTYwODgwNjQ3._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/w1oA9OEWjDzLbJPo575Eor9HoK5.jpg',
#   u'rating': u'G',
#   u'revenue': 169327687,
#   u'score_imdb': 7.3,
#   u'score_metascore': 70,
#   u'score_rtcritics': 85,
#   u'title': u"The Emperor's New Groove"},
#  {u'_id': u'KavGuzEiPnXBvNDhf',
#   u'actors': u'Leopold Stokowski, Steve Martin, Itzhak Perlman, Quincy Jones, Bette Midler',
#   u'directors': u'James Algar, Gaetan Brizzi',
#   u'genres': [u'Animation'],
#   u'plot': u'An update of the original film with new interpretations of great works of classical music.',
# ...
#   u'rating': u'PG',
#   u'revenue': 80035402,
#   u'score_imdb': 6.4,
#   u'score_rtcritics': 56,
#   u'title': u'Footloose'},
#  {u'_id': u'7XfwEHC4XkkKPCsxZ',
#   u'actors': u'Richard Dreyfuss, Holly Hunter, Brad Johnson, John Goodman, Audrey Hepburn',
#   u'directors': u'Steven Spielberg',
#   u'genres': [u'Drama', u'Fantasy', u'Romance'],
#   u'plot': u"Pete Sandich and buddy Al Yackey are daredevil aerial forest-fire fighters. Pete finds True Love with Dorinda but won't give up the job. When he takes one risk too many, Dorinda faces deep grief and cannot easily put her life back together.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjAxMjM3NzI5Ml5BMl5BanBnXkFtZTcwNDQ1NTMyMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/lwIXkqlrzAGLmgvzZNKyzOcsVn1.jpg',
#   u'rating': u'PG',
#   u'revenue': 74134790,
#   u'score_imdb': 6.4,
#   u'score_metascore': 50,
#   u'score_rtcritics': 64,
#   u'title': u'Always'},
#  {u'_id': u'35e2xKaCf4ZqRHYCv',
#   u'actors': u'William Campbell, Billy Campbell, Jennifer Connelly, Alan Arkin, Timothy Dalton',
#   u'directors': u'Joe Johnston',
#   u'genres': [u'Action', u'Science Fiction', u'Adventure', u'Family'],
#   u'plot': u"Young 1930's pilot Cliff Secord stumbles on a top secret rocket-pack and with the help of his mechanic/mentor, Peevee, he attempts to save his girl and stop the Nazis as The Rocketeer.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMzEyMjI2OTQxOF5BMl5BanBnXkFtZTcwODUxMjEyMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/tFOoAfyznMdCRJIvX3vDOpr3MCg.jpg',
#   u'rating': u'PG',
#   u'revenue': 62000000,
#   u'score_imdb': 6.4,
#   u'score_rtcritics': 61,
#   u'title': u'The Rocketeer'},
#  {u'_id': u'RnCKtMXQMKgD5vqJ6',
#   u'actors': u'Emilio Estevez, Joss Ackland, Lane Smith, Heidi Kling, Josef Sommer',
#   u'directors': u'Stephen Herek',
#   u'genres': [u'Comedy', u'Family'],
#   u'plot': u'As punishment for getting a DUI, hotshot lawyer Gordon Bombay is sentenced to community service coaching the pathetic Mighty Ducks hockey team. Initially reluctant, Gordon eventually transforms the ragtag band of outsiders and misfits into the No. 1 team in the peewee league, overcoming his own childhood trauma in the process.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTIzMzgxOTQwMV5BMl5BanBnXkFtZTcwMzkzNDYyMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/gRHJJGnE5bE8kMyMuB2MvEWnd94.jpg',
#   u'rating': u'PG',
#   u'revenue': 50752337,
#   u'score_imdb': 6.4,
#   u'score_rtcritics': 15,
#   u'title': u'The Mighty Ducks'},
#  {u'_id': u'JdGqPydFee5QEvojP',
#   u'actors': u'Zachary Gordon, Robert Capron, Devon Bostick, Steve Zahn, Rachael Harris',
#   u'directors': u'David Bowers',
#   u'genres': [u'Comedy', u'Family'],
#   u'plot': u'School is out and Greg is ready for the days of summer, when all his plans go wrong. What on earth is he going to do all summer?',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTc2MTk4MTk4Nl5BMl5BanBnXkFtZTcwMzgzOTY2Nw@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/6u3rWg02AfbmAm4zPOapmOjUJEz.jpg',
#   u'rating': u'PG',
#   u'revenue': 49002815,
#   u'score_imdb': 6.4,
#   u'score_metascore': 54,
#   u'score_rtcritics': 51,
#   u'title': u'Diary of a Wimpy Kid: Dog Days'},
#  {u'_id': u'bis6MqSZNGWkixeRw',
#   u'actors': u'Freddie Highmore, Kristen Bell, Nicolas Cage, Bill Nighy, Nathan Lane',
#   u'directors': u'David Bowers',
#   u'genres': [u'Action', u'Science Fiction', u'Animation', u'Family'],
#   u'plot': u"Set in futuristic Metro City, Astro Boy is about a young robot with incredible powers created by a brilliant scientist in the image of the son he has lost. Unable to fulfill the grieving man's expectations, our hero embarks on a journey in search of acceptance, experiencing betrayal and a netherworld of robot gladiators, before he returns to save Metro City and reconcile with the father who had rejected him.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTI5NTEwNTcxMl5BMl5BanBnXkFtZTcwMDEyMTE4Mg@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/4kQczIhUFTnDWwG6HKsgCxLoi6.jpg',
#   u'rating': u'PG',
#   u'revenue': 44091067,
#   u'score_imdb': 6.4,
#   u'score_metascore': 53,
#   u'score_rtcritics': 49,
#   u'title': u'Astro Boy'},
#  {u'_id': u'GxmAQtk5wA3sMebbi',
#   u'actors': u'Byron Keith Minns, Richard Pryor, John Candy, Lonette McKee, Stephen Collins',
#   u'directors': u'Walter Hill',
#   u'genres': [u'Comedy'],
#   u'plot': u"Brewster, an aging minor-league baseball player, stands to inherit 300 million dollars if he can successfully spend 30 million dollars in 30 days without anything to show for it, and without telling anyone what he's up to... A task that's a lot harder than it sounds!",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjAzOTE2MzA2NF5BMl5BanBnXkFtZTYwMTM0NTg4._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/s7cLuqvHw866brIoAtmqLC0AbGO.jpg',
#   u'rating': u'PG',
#   u'revenue': 40800000,
#   u'score_imdb': 6.4,
#   u'score_rtcritics': 38,
#   u'title': u"Brewster's Millions"},
#  {u'_id': u'Hi2ERAXfaxfKLdwGu',
#   u'actors': u'Don Cheadle, Sophie Okonedo, Nick Nolte, Joaquin Phoenix, Desmond Dube',
#   u'directors': u'Terry George',
#   u'genres': [u'Drama', u'War', u'History'],
#   u'plot': u'Inspired by true events, this film takes place in Rwanda in the 1990\u2019s when more than a million Tutsis\u2019 were killed in a genocide that went mostly unnoticed by the rest of the world. Hotel owner Paul Rusesabagina houses over a thousand refuges in his hotel in attempt to save their lives.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTI2MzQyNTc1M15BMl5BanBnXkFtZTYwMjExNjc3._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/ux6TRpqIOv6h8VJAiDVQBy2LBBH.jpg',
#   u'rating': u'PG-13',
#   u'revenue': 38000000,
#   u'score_imdb': 8.2,
#   u'score_metascore': 79,
#   u'score_rtcritics': 90,
#   u'title': u'Hotel Rwanda'},
#  {u'_id': u'4gqPH4nwpwXvGpA53',
#   u'actors': u'Anna Sophia Robb, Annasophia Robb, Jeff Daniels, Cicely Tyson, Dave Matthews',
#   u'directors': u'Wayne Wang',
#   u'genres': [u'Drama', u'Comedy', u'Family'],
#   u'plot': u"A girl, abandoned by her mother when she was three, moves to a small town in Florida with her father. There, she adopts an orphaned dog she names Winn-Dixie. The bond between the girl and her special companion brings together the people in a small Florida town and heals her own troubled relationship with her father. Based on the children's novel 'Because of Winn-Dixie' (2000) by Kate DiCamillo.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTA3NDYzNDE0MjBeQTJeQWpwZ15BbWU3MDc3NjA3MzM@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/lQChu1qq8V05SXL9OY2GSvLbN79.jpg',
#   u'rating': u'PG',
#   u'revenue': 32645546,
#   u'score_imdb': 6.4,
#   u'score_metascore': 54,
#   u'score_rtcritics': 54,
#   u'title': u'Because of Winn-Dixie'},
#  {u'_id': u'DNPfvin99gwCd4eav',
#   u'actors': u'Scott Adams, Amy Adams, Matthew Goode, Adam Scott, John Lithgow',
#   u'directors': u'Anand Tucker',
#   u'genres': [u'Romance', u'Comedy'],
#   u'plot': u'A woman who has an elaborate scheme to propose to her boyfriend on Leap Day, an Irish tradition which occurs every time the date February 29 rolls around, faces a major setback when bad weather threatens to derail her planned trip to Dublin. With the help of an innkeeper, however, her cross-country odyssey just might result in her getting engaged.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTgzMTQ2MDQxMF5BMl5BanBnXkFtZTcwODEzOTg5Mg@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/9UWKpkQvZaPqpb85Or4e0PghJft.jpg',
#   u'rating': u'PG',
#   u'revenue': 29922472,
#   u'score_imdb': 6.4,
#   u'score_metascore': 33,
#   u'score_rtcritics': 21,
#   u'title': u'Leap Year'},
#  {u'_id': u'vFFHH2Pu4XpFvQHG3',
#   u'actors': u'Melody Anderson, Sam J. Jones, Topol, Max von Sydow, Ornella Muti',
#   u'directors': u'Mike Hodges',
#   u'genres': [u'Science Fiction'],
#   u'plot': u'A football player and his friends travel to the planet Mongo and find themselves fighting the tyrant, Ming the Merciless, to save Earth.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjE1OTU3ODAwMl5BMl5BanBnXkFtZTcwMzQ2NjczNA@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/9c5vKUX7MB1yixVp0ZFAUDRTaeE.jpg',
#   u'rating': u'PG',
#   u'revenue': 27107960,
#   u'score_imdb': 6.4,
#   u'score_metascore': 63,
#   u'score_rtcritics': 81,
#   u'title': u'Flash Gordon'},
#  {u'_id': u'bxnZyuhBtzL22W86a',
#   u'actors': u"Robby Benson, Glynnis O'Connor, Joan Hotchkis, Sandy McPeak, James Best",
#   u'directors': u'Max Baer Jr.',
#   u'genres': [u'Drama', u'Romance'],
#   u'plot': u"Billy Joe confesses his love to the lovely Bobbi Lee only to cover his growing fear that he may, in fact, be homosexual. One night, at a barn dance, he gets a little drunk and rather than going with the hired whores, gives into his desires and sexual relations with an unnamed man. The guilt causes him to run away, hide in the woods and eventually confess everything to Bobbi Lee who doesn't want to believe him only because she was enjoying the forbidden nature of their love. In the end, he cannot accept his sexuality nor can he hide behind Bobbi Lee and that's why he throws himself off the Tallahachee bridge.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTQ1NTk1ODcwMl5BMl5BanBnXkFtZTYwNzM2ODg5._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/96Dg3c79P0Fqgr2OAG9aWe6ceAR.jpg',
#   u'rating': u'PG',
#   u'revenue': 27000000,
#   u'score_imdb': 6.4,
#   u'title': u'Ode to Billy Joe'},
#  {u'_id': u'EEGwRoiu38399EwJ9',
#   u'actors': u'Robert Redford, Mia Farrow, Sam Waterston, Bruce Dern, Karen Black',
#   u'directors': u'Jack Clayton',
#   u'genres': [u'Drama', u'Romance'],
#   u'plot': u"Nick Carraway, a young Midwesterner now living on Long Island, finds himself fascinated by the mysterious past and lavish lifestyle of his neighbor, the nouveau riche Jay Gatsby. He is drawn into Gatsby's circle, becoming a witness to obsession and tragedy.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjY4NDQ3OTk1OF5BMl5BanBnXkFtZTgwMjQ3NzMxMDE@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/70FxgKoE8UXDYc8IZL0b6rMvNFD.jpg',
#   u'rating': u'PG',
#   u'revenue': 26533200,
#   u'score_imdb': 6.4,
#   u'score_metascore': 43,
#   u'score_rtcritics': 39,
#   u'title': u'The Great Gatsby'},
#  {u'_id': u'KvK4KsLWs54RpEtNg',
#   u'actors': u'Lindsay Rich, Brandon Call, Gregory Levinson, Phil Fondacaro, Wayne Allwine',
#   u'directors': u'Ted Berman, Richard Rich',
#   u'genres': [u'Fantasy', u'Animation'],
#   u'plot': u'Taran is an assistant pigkeeper with boyish dreams of becoming a great warrior. However, he has to put the daydreaming aside when his charge, an oracular pig named Hen Wen, is kidnapped by an evil lord known as the Horned King. The villain hopes Hen will show him the way to The Black Cauldron, which has the power to create a giant army of unstoppable soldiers.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BNjMwNDU2ODk1M15BMl5BanBnXkFtZTcwMjg4MDYyMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/dteeon90jLwZtQurCFfP2ivG4ZG.jpg',
#   u'rating': u'PG',
#   u'revenue': 21288692,
#   u'score_imdb': 6.4,
#   u'score_rtcritics': 55,
#   u'title': u'The Black Cauldron'},
#  {u'_id': u'8YgyewKGairbqxN22',
#   u'actors': u'Peter Falk, D.B. Sweeney, Julianne Moore, Jan Rubes, Frankie Faison',
#   u'directors': u'Peter Yates',
#   u'genres': [],
#   u'plot': u'An elderly yet young-at-heart man moves in with his grandson, and both their lives turn upside-down.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTQyNjMzMTkzN15BMl5BanBnXkFtZTcwOTY4NzkyMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/dXtNDFN0Metdy7OK2QqnuRu1SLv.jpg',
#   u'rating': u'PG',
#   u'revenue': 12400000,
#   u'score_imdb': 6.4,
#   u'score_rtcritics': 29,
#   u'title': u'Roommates'},
#  {u'_id': u'ngFnRnwigd3TmuvxD',
#   u'actors': u'Cathy Cavadini, Tara Strong, Tom Kenny, Kevin Michael Richardson, E.G. Daily',
#   u'directors': u'Kim Jong-ho, Jeong Chang-Yul',
#   u'genres': [u'Action', u'Family'],
#   u'plot': u"The Powerpuff Girls Movie (known within the film simply as The Powerpuff Girls) is a 2002 American animated film based on the Cartoon Network animated television series of the same name. Produced by Cartoon Network Studios for Warner Bros. and Cartoon Network, the film debuted in the United States on July 3, 2002. It was more or less a prequel of the series, telling the origin story of how the Powerpuff Girls were created and how they came to be the defenders of Townsville. The film performed poorly at the box office. It was the first Hanna-Barbera/Cartoon Network Studios theatrical feature film since 1993's Once Upon a Forest, and is the only film based on a Cartoon Network series to be released theatrically. The movie shows the origin of the Powerpuff Girls before the cartoon series. It explains why they were born and why they dedicated their lives to fighting crime and the forces of evil.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjE4NTY0NjQ5OF5BMl5BanBnXkFtZTYwMTE3NTY3._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/1R9tS8i4ObLHDBe5gLRW7XYAZnk.jpg',
#   u'rating': u'PG',
#   u'revenue': 11411644,
#   u'score_imdb': 6.4,
#   u'score_metascore': 65,
#   u'score_rtcritics': 63,
#   u'title': u'The Powerpuff Girls'},
#  {u'_id': u'qW8mfeF3hLWiZY8Wm',
#   u'actors': u'John Goodman, Cathy Moriarty, Simon Fenton, Omri Katz, Lisa Jakub',
#   u'directors': u'Joe Dante',
#   u'genres': [u'Drama', u'Comedy', u'Family'],
#   u'plot': u'A showman introduces a small coastal town to a unique movie experience and capitalises on the Cuban Missile crisis hysteria with a kitschy horror extravaganza combining film effects, stage props and actors in rubber suits in this salute to the B-movie.',
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTc0NzU5MjM0N15BMl5BanBnXkFtZTcwMjkwODYxMQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/8e9ez0wPLwNyj0qwfMyg8Ymveen.jpg',
#   u'rating': u'PG',
#   u'revenue': 9532895,
#   u'score_imdb': 6.7,
#   u'score_rtcritics': 93,
#   u'title': u'Matinee'},
#  {u'_id': u'SsFKoFXMNx6ZJwqnY',
#   u'actors': u'Daniel Radcliffe, Rupert Grint, Emma Watson, Helena Bonham Carter, Ralph Fiennes',
#   u'directors': u'David Yates',
#   u'genres': [u'Fantasy', u'Adventure', u'Family'],
#   u'plot': u"In the second installment of the two-part conclusion, Harry and his best friends, Ron and Hermione, continue their quest to vanquish the evil Voldemort once and for all. Just as things begin to look hopeless for the young wizards, Harry discovers a trio of magical objects that endow him with powers to rival Voldemort's formidable skills.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMTY2MTk3MDQ1N15BMl5BanBnXkFtZTcwMzI4NzA2NQ@@._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/7xmtxRc9nQnCuWINuTT4SMP5NJc.jpg',
#   u'rating': u'PG-13',
#   u'revenue': 1327817822,
#   u'score_imdb': 8.1,
#   u'score_metascore': 87,
#   u'score_rtcritics': 96,
#   u'title': u'Harry Potter and the Deathly Hallows: Part 2'},
#  {u'_id': u'2X3xxXYaoAGQEbP4B',
#   u'actors': u'Johnny Depp, Geoffrey Rush, Orlando Bloom, Keira Knightley, Jack Davenport',
#   u'directors': u'Gore Verbinski',
#   u'genres': [u'Action', u'Fantasy', u'Adventure'],
#   u'plot': u"Jack Sparrow, a freewheeling 17th-century pirate who roams the Caribbean Sea butts heads with a rival pirate bent on pillaging the village of Port Royal. When the governor's daughter is kidnapped, Sparrow decides to help the girl's love save her. But their seafaring mission is hardly simple.",
#   u'poster': u'http://ia.media-imdb.com/images/M/MV5BMjAyNDM4MTc2N15BMl5BanBnXkFtZTYwNDk0Mjc3._V1_SX300.jpg',
#   u'poster_1': u'http://image.tmdb.org/t/p/w185/tkt9xR1kNX5R9rCebASKck44si2.jpg',
#   u'rating': u'PG-13',
#   u'revenue': 655011224,
#   u'score_imdb': 8.1,
#   u'score_metascore': 63,
#   u'score_rtcritics': 79,
#   u'title': u'Pirates of the Caribbean: The Curse of the Black Pearl'}]

# %%
job
